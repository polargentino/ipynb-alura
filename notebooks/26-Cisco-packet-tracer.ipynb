# %% [markdown]
# He corregido y consolidado el texto que me proporcionaste. Eliminé las secciones repetidas y el contenido duplicado para crear un documento coherente y limpio, manteniendo el formato y la escritura original de Cisco.
#
# ---
#
# # 1.0.1 Video - Bienvenido a Introducción a Cisco Packet Tracer
# ## 1.0 Instale Cisco Packet Tracer
# # Cisco Packet Tracer - Introducción
#
# (Comienza la música rock rápido)
#
# Ya sea que esté buscando un trabajo en tecnología,
# explorando sus opciones de carrera,
# o simplemente quiera ampliar sus habilidades,
# obtener experiencia en la construcción de redes
# nunca ha sido tan fácil como ahora.
#
# Conozca la herramienta de simulación de redes de Cisco, **Cisco Packet Tracer**.
# Este entorno de laboratorio virtual
# le permite practicar networking,
# Internet de las cosas y ciberseguridad.
#
# Con Packet Tracer,
# aplica habilidades reales de creación de redes,
# y adquiere una valiosa experiencia desde su propio ordenador,
# sin necesidad de hardware especializado.
#
# **Cisco Packet Tracer** es una herramienta de aprendizaje increíblemente poderosa
# con múltiples modos que te permiten
# explorar el vasto mundo de las redes.
#
# En **modo Simulación**,
# se sumerge en cómo funciona realmente una red.
# Cree una vista lógica de su red,
# configure sus dispositivos,
# y siga cómo los paquetes de datos viajan por su red.
#
# Incluso puede explorar lo que hay dentro de cada paquete
# para obtener una vista más profunda.
#
# Después de eso,
# el **modo físico** lo coloca en el laboratorio virtual
# para ver cómo su visión lógica
# se traduce en dispositivos y cables físicos.
#
# Practicará cómo configurar su propio estante de dispositivos
# y seleccionar los cables y puertos correctos.
#
# Packet Tracer también tiene un **tutor inteligente incorporado**
# para darle pistas en el camino,
# pero solo si lo desea.
#
# Una vez que lo domine,
# lleva sus habilidades aún más lejos
# mediante la creación de redes avanzadas con dispositivos **IoT**,
# integración de código **Python**,
# o practicando sus habilidades de **automatización de redes**.
#
# La mejor parte es que **Cisco Packet Tracer es absolutamente gratuito**.
#
# Es momento de terminar con el video,
# **Curso de Introducción a Cisco Packet Tracer**.
#
# Pruébelo hoy mismo en [skillsforall.com](https://skillsforall.com),
# ofrecido por Cisco Networking Academy.
#
# ---
#
# # 1.0.2 Primera vez en el curso
# ## Primera vez en este curso
# El curso Introducción a Cisco Packet Tracer está diseñado para los nuevos usuarios de la herramienta de simulación y visualización de redes Cisco Packet Tracer. Ya sea que sea un estudiante sin conocimientos de redes, un estudiante con experiencia en redes o un estudiante actualmente inscrito en un curso que requiere el uso de Packet Tracer, ¡este curso lo ayudará a comenzar!
#
# El software gratuito Cisco Packet Tracer lo ayuda a practicar su configuración de red y habilidades de resolución de problemas utilizando su computadora de escritorio o computadora portátil. Le permite simular redes sin tener acceso a equipos físicos. Además de la creación de redes, puede aprender y luego practicar sus habilidades de Internet de las cosas (IoT) y ciberseguridad. Puede elegir crear una red desde cero, usar una red de muestra prediseñada o completar tareas de laboratorio. Si bien Packet Tracer no reemplaza la práctica en enrutadores, conmutadores, firewalls y servidores físicos, ¡ofrece muchos beneficios!
#
# Este curso autoguiado lo ayudará a familiarizarse con el software Packet Tracer que se utiliza en muchos otros cursos de Cisco Networking Academy. El curso se centra en explorar la interfaz de Packet Tracer, incluidos los menús, los iconos y los dispositivos que se utilizan en la creación de redes.
#
# ### Recursos disponibles para usted
# Las preguntas frecuentes sobre se pueden encontrar en [https://www.netacad.com/help](https://www.netacad.com/help) o haciendo clic en Help en la barra de navegación superior. Para obtener ayuda con la descarga de Packet Tracer, visite [https://www.netacad.com/resources/lab-downloads](https://www.netacad.com/resources/lab-downloads) y desplácese hacia abajo hasta Recursos de aprendizaje (Learning Resources).
#
# Puede encontrar preguntas frecuentes adicionales visitando nuestro asistente virtual, Morgan. Haga clic en el ícono de chat en la esquina superior derecha para elegir entre una lista de temas o ingresar tu pregunta. La ayuda de Morgan incluye información sobre Packet Tracer, certificados e insignias.
#
# ---
#
# ## 1.0.3 Descargue Cisco Packet Tracer
# Para obtener e instalar su copia de Cisco Packet Tracer, siga las instrucciones del siguiente enlace: [https://www.netacad.com/resources/lab-downloads](https://www.netacad.com/resources/lab-downloads)
#
# ---
#
# ## Placeholder graphic
#
# ---
#
# ## 1.0.4 ¿Por qué debería realizar este curso?
# ¿Qué pasaría si pudiera ver el interior de una red de pequeñas empresas o de Internet? ¿Alguna vez ha querido configurar un sistema de IoT para que le avise por teléfono cuando hay un problema en el entorno de su hogar? Bienvenido a Cisco Packet Tracer – el entorno de simulación que puede ayudarlo a hacer todo eso y mucho más.
#
# El curso Introducción a Cisco Packet Tracer está diseñado para familiarizarlo con la herramienta de simulación y visualización de redes Cisco Packet Tracer.
#
# El curso tiene dos módulos. En el primer módulo, Introducción a Cisco Packet Tracer, aprenderá a instalar el software y a explorar la interfaz. Además del texto, hay siete videos y una actividad de exploración práctica.
#
# Una vez que se haya familiarizado con la interfaz de Cisco Packet Tracer, tomará el segundo módulo, Crear una Red Cisco Packet Tracer. Creará su propia red en Packet Tracer (PT). También aprenderá acerca de los diferentes tipos de archivos PT. Este módulo tiene cinco vídeos y una actividad de Packet Tracer.
#
# ¡Comencemos con Cisco Packet Tracer!
#
# ---
#
# # 1.0.5 Video - Resumen de Cisco Packet Tracer
# Haga clic en Reproducir en el vídeo para ver una breve descripción general de Packet Tracer.
# # Cisco Packet Tracer - Presentación
#
# Nos gustaría presentarle
# una herramienta de simulación de red gratuita: **Cisco Packet Tracer**.
#
# El software Cisco Packet Tracer
# le permite practicar la configuración de su red
# y habilidades de solución de problemas
# utilizando su ordenador de sobremesa o portátil.
#
# Además, le permite simular redes
# sin tener acceso a equipo físico.
#
# Y más allá de la creación de redes básicas,
# también le permite aprender y practicar **Internet de las cosas**
# y habilidades de **ciberseguridad**.
#
# ---
#
# ## Ejemplos y usos de Cisco Packet Tracer
#
# * Abra un archivo de **topología** o **actividad existente**.
# * Simule el **equipo de cable y montaje en rack**
#     como si estuviera en una instalación de red física.
# * Diseñe, planifique y pruebe **esquemas y direccionamiento IP**.
# * Configure **dispositivos inalámbricos** y **seguridad inalámbrica**.
# * Configure y programe **dispositivos IoT**
#     como sensores y actuadores.
# * Cree y pruebe componentes de **domótica**.
#
# Por ejemplo:
# el termostato inteligente en el rociador de césped que se muestra aquí.
#
# ---
#
# ## Exploración
#
# * Abra un archivo de ejemplo desde una **red prediseñada**.
# * Observe el **flujo de datos en la red**
#     y vea información detallada de cada **paquete**.
# * Empiece con una **pantalla en blanco**
#     y construya una topología simple o compleja desde cero.
#
# ---
#
# ## Aprendizaje y evaluación
#
# Packet Tracer no es solo una poderosa herramienta de aprendizaje,
# sino también un **instrumento de evaluación**.
#
# Al tomar clases que incluyen Packet Tracer,
# puede realizar diferentes actividades
# y **evaluaciones de habilidades**.
#
# ---
#
# ## Disponibilidad
#
# **Cisco Packet Tracer** está disponible para:
# * Windows
# * Mac
# * Linux
#
# ---
#
# 🎓 Disfrute aprendiendo y explorando con **Cisco Packet Tracer**.
#
# ---
#
# # 1.1.1 Video - La Interfaz de Usuario de Packet Tracer
# ## 1.1 La interfaz de Cisco Packet Tracer
# 1.1.1 Video - La Interfaz de Usuario de Packet Tracer
# Packet Tracer es una herramienta que permite simular redes reales. Proporcione tres menús principales que puede utilizar para lo siguiente:
#
# * Puede agregar dispositivos y conectarlos a través de cables o de forma inalámbrica.
# * Puede seleccionar, eliminar, inspeccionar, etiquetar y agrupar componentes dentro de la red.
# * Administre su red
#
# El menú de administración de red le permite hacer lo siguiente:
#
# * Abrir una red existente/de muestra
# * Guarda tu red actual
# * Modifica tu perfil de usuario o tus preferencias
#
# Haga clic en Reproducir en el video para aprender a utilizar los menús y navegar por la interfaz.
#
# ## # Getting Started con Cisco Packet Tracer: La interfaz de usuario
#
# Bienvenido a **Getting Started con Cisco Packet Tracer: La interfaz de usuario**.
# Echemos un vistazo a algunos de los componentes principales de **Cisco Packet Tracer**.
#
# ---
#
# ## Menú superior
#
# En la parte superior hay diferentes opciones de menú.
#
# * **Archivo**
#     Incluye opciones estándar como **Nuevo**, **Abrir**, **Guardar** y **Guardar como**.
#     También encontrarás **Muestras abiertas**, que incluyen dispositivos y ejemplos de protocolo incorporados en cada nueva versión de Packet Tracer.
#
# * **Preferencias (Opciones)**
#     * **Interfaz:** personaliza la experiencia del usuario, mostrando etiquetas de modelo y nombre de los dispositivos.
#     * **Fuente:** ajusta tamaño, tipo y color de la fuente.
#     * **Opciones diversas:** define el intervalo de copia de seguridad automática de archivos (desactivado por defecto).
#
# ---
#
# ## Barra de herramientas
#
# * **Barra principal:** incluye iconos de uso común como **Deshacer**, **Acercar** y **Alejar**.
# * **Barra secundaria:** permite seleccionar o eliminar objetos, e incluir objetos de dibujo.
#
# ---
#
# ## Barra de herramientas del espacio de trabajo
#
# En la parte superior azul encontrarás:
#
# * **Botón lógico** y **Botón físico**:
#     * **Vista lógica:** muestra cómo se conectan los dispositivos y cómo fluyen los datos en la red.
#     * **Vista física:** muestra la disposición física de equipos, con estantes, routers, switches, PCs y su cableado.
#
# ---
#
# ## Barra inferior
#
# * **Iconos principales:**
#     * **Encender/apagar dispositivos**.
#     * **Avance rápido:** hace converger rápidamente la red sin esperar los protocolos.
#
# * **Modo de simulación:**
#     * **Tiempo real:** reproduce los procesos en tiempo real.
#     * **Simulación:** permite controlar el tiempo, añadir paquetes y ver cómo viajan a través de la red.
#
# ---
#
# ## Componentes de red
#
# En la parte inferior izquierda:
# * Routers
# * Switches
# * PCs
# * Otros dispositivos
# * Cables para conexiones
#
# ---
#
# ## Cuadro de escenario
#
# En la parte inferior derecha se encuentra el **cuadro de escenario**, donde:
# * Puedes crear paquetes en la red.
# * Visualizar cómo atraviesan múltiples dispositivos.
# * Analizar su recorrido paso a paso.
#
# ---
#
# 🎓 **Disfrute explorando y aprendiendo con Cisco Packet Tracer.**
#
# ---
#
# # 1.1.2 Vídeo: Implementación de dispositivos
# Ahora que está familiarizado con la interfaz y los menús, puede comenzar a implementar dispositivos en Packet Tracer.
#
# Haz clic en Reproducir en el video para aprender a implementar dispositivos.
#
# # Introducción con Cisco Packet Tracer: Implementación de dispositivos
#
# Bienvenido a **Introducción con Cisco Packet Tracer: Implementación de dispositivos**.
#
# En esta sección aprenderemos cómo seleccionar, agregar y conectar dispositivos dentro de **Packet Tracer** para construir una red doméstica sencilla.
#
# ---
#
# ## Componentes de red
#
# En la parte inferior izquierda de Cisco Packet Tracer se encuentran los **componentes de la red**.
# Aquí se pueden seleccionar:
# * Enrutadores
# * Conmutadores
# * Computadoras
# * Dispositivos adicionales (ej. cámaras web, sensores, etc.)
# * Cableado para las conexiones
#
# ### Organización
# * **Fila superior:** categorías
# * **Fila inferior:** subcategorías
#
# ---
#
# ## Creación de una red doméstica
#
# 1.  **Seleccionar un router doméstico**
#     * Los routers corporativos están en la categoría de enrutadores.
#     * Para un hogar, se debe elegir un **router inalámbrico** en la categoría **Dispositivos inalámbricos**.
#
# 2.  **Agregar dispositivos finales**
#     * Una **PC para juegos**.
#     * Una **computadora portátil**.
#     * Un **dispositivo adicional**: por ejemplo, una cámara en la puerta principal.
#
# 3.  **Agregar dispositivos IoT**
#     * Ir a la subcategoría **Home**.
#     * Seleccionar un dispositivo, como una **cámara web**, y arrastrarlo a la topología.
#
# ---
#
# ## Herramientas de navegación
#
# * **Acercar/Alejar:** facilita la visualización de la topología.
# * **Barras de desplazamiento:** permiten mover la vista si la topología queda fuera de la pantalla.
# * **Reset (R):** devuelve la vista al tamaño inicial.
#
# ---
#
# ## Función de eliminación
#
# * Seleccione la herramienta **Delete (Eliminar)**.
# * Haga clic en el dispositivo que desea borrar.
# * Confirmar la eliminación.
# * En caso de error, use **Deshacer** para recuperar el dispositivo.
#
# ---
#
# ## Cableado de dispositivos
#
# 1.  **Conexiones**
#     * Categoría de **conexiones** (parte inferior).
#     * Opciones:
#         * **Rayo (conexión automática)**: selecciona el puerto y cable adecuado.
#         * **Cables específicos**: si sabe qué tipo utilizar.
#
# 2.  **Ejemplos de conexiones**
#     * Router inalámbrico ↔ PC (automáticamente selecciona el puerto y cable).
#     * Router inalámbrico ↔ cámara web IoT.
#
# ---
#
# ## Configuración de una laptop con Wi-Fi
#
# 1.  Seleccione la **laptop** en la topología.
# 2.  Por defecto, viene con **tarjeta de red con cable**.
# 3.  Pasos para cambiarla:
#     * **Apagar la laptop**.
#     * Quitar la tarjeta de red con cable (arrastrándola hacia fuera).
#     * Instalar la **tarjeta inalámbrica**.
#     * Encender nuevamente la laptop.
#
# 4.  Resultado:
#     * La laptop se conectará automáticamente al **router inalámbrico**.
#
# ---
#
# ## Conclusión
#
# Hemos creado una pequeña red doméstica en Packet Tracer, que incluye:
# * Router inalámbrico
# * PC
# * Laptop con conexión Wi-Fi
# * Cámara web IoT
#
# 🎓 **Disfrute explorando y aprendiendo con Cisco Packet Tracer.**
#
# ---
#
# # 1.1.3 Configuración de GUI y CLI en Cisco Packet Tracer
# Packet Tracer también proporciona una variedad de pestañas para la configuración del dispositivo incluidas las siguientes:
#
# * Física
# * Configuración
# * CLI
# * Escritorio
# * Servicios
#
# Las pestañas que se muestran dependen del dispositivo que esté configurando actualmente.
#
# Nota: Es posible que veas otras pestañas en diferentes dispositivos. Estas pestañas adicionales están fuera del alcance de este curso.
#
# Haga clic a continuación para obtener más información sobre las pestañas relevantes para este curso.
#
# ## Pestaña física
#
# La pestaña Física proporciona una interfaz para interactuar con el dispositivo que incluye encenderlo o apagarlo o instalar diferentes módulos, como una tarjeta de interfaz de red inalámbrica (NIC).
#
# ## Pestaña Configuración
#
# Para los dispositivos intermedios, como enrutadores y conmutadores, hay dos formas de acceder a las configuraciones de los dispositivos. Se puede acceder a las configuraciones a través de la pestaña Config que es una interfaz gráfica de usuario (GUI). También se puede acceder a las configuraciones mediante una interfaz de línea de comandos (CLI).
#
# La pestaña Configuración no simula la funcionalidad de un dispositivo. Esta pestaña es exclusiva de Packet Tracer. Si no sabe cómo usar la interfaz de línea de comandos, esta pestaña proporciona una forma de usar una GUI exclusiva de Packet Tracer para configurar los ajustes básicos. A medida que se cambian los ajustes en la GUI, los comandos CLI equivalentes aparecen en la ventana Comandos IOS equivalentes. Esto le ayuda a aprender los comandos de la CLI y el Sistema Operativo de Interconexión de Redes de Cisco (IOS) mientras utiliza la pestaña Configuración.
#
# Por ejemplo, en la figura, el usuario ha configurado MyRouter como el nombre del dispositivo. La ventana Comandos IOS equivalentes muestra el comando IOS que logra los mismos resultados en la CLI.
#
# Además, los archivos de configuración del dispositivo se pueden guardar, cargar, borrar y exportar aquí.
#
# ## Pestaña CLI
#
# La pestaña CLI proporciona acceso a la interfaz de línea de comandos de un dispositivo Cisco. El uso de la pestaña CLI requiere conocimiento de la configuración del dispositivo con IOS. Aquí, puede practicar la configuración de dispositivos Cisco en la línea de comandos. La configuración de CLI es una habilidad necesaria para implementaciones de redes más avanzadas.
#
# Nota: Todos los comandos que se ingresaron desde la pestaña Configuración también se muestran en la pestaña CLI.
#
# ## Pestaña Escritorio
#
# Para algunos dispositivos finales, como PC y portátiles, Packet Tracer proporciona una interfaz de escritorio que le da acceso a la configuración de IP, la configuración inalámbrica, el símbolo del sistema, un navegador web y otras aplicaciones.
#
# ## Pestaña Servicios
#
# Un servidor tiene todas las funciones de un host con la adición de una pestaña más, la pestaña Services (Servicios). Esta pestaña permite configurar un servidor con procesos de servidor comunes, como HTTP, DHCP, DNS u otros servicios, como se muestra en la figura.
#
# ---
#
# # 1.1.4 Video - Actividad supervisada de Packet Tracer
# ¿Qué pasaría si pudieras ver el interior de una red de pequeñas empresas o de internet? Tal vez quieras configurar un sistema de Internet de las Cosas (IoT) para que te alerte por teléfono cuando hay un problema en el entorno de tu hogar.
#
# **Packet Tracer** te permitirá hacer esta prueba de red sin tener el equipo físico.
#
# ### Bienvenido a Cisco Packet Tracer
#
# Packet Tracer es un entorno de simulación que puede ayudarte a hacer todo eso y mucho más. Te permite conectar y configurar dispositivos de red incluso si no tienes acceso a equipo físico.
#
# En esta **Actividad Asistida por Packet Tracer (PTTA)**, serás guiado como si tuvieras un profesor mirando por encima del hombro, ayudándote cuando lo necesites.
#
# ### Sistema de Sugerencias de PTTA
#
# Todas las actividades PTTA incluyen consejos para ayudarte a completar las tareas. Tú eliges el nivel de sugerencias que ves, lo que te permite ajustar la cantidad de apoyo que recibes. Esto te da la oportunidad de ponerte a prueba en niveles de dificultad graduados.
#
# El sistema de sugerencias de PTTA te apoyará a medida que aprendes. Podrás ver algunas PTTA en otros cursos, pero ten en cuenta que no todas las actividades de Packet Tracer son PTTA. Los otros tipos de actividades de Packet Tracer no tienen este sistema de sugerencias.
#
# Este PTTA en particular también tiene un tutorial incorporado para ayudarte a aprender a usar las actividades de la PTTA.
#
# ### Comencemos con la actividad
#
# Esta actividad te llevará más allá de la exploración. Requiere que conectes dispositivos a la red, instales un enrutador de respaldo y configures un nombre de host. Serás apoyado por el sistema de sugerencias en cada paso del camino.
#
# Primero, decide tu nivel de sugerencia, desde "ninguna sugerencia" hasta "todas las sugerencias". Para esta demostración, se ha elegido la configuración predeterminada de todas las sugerencias.
#
# Antes de comenzar, asegúrate de leer la información de antecedentes y escenarios. Esto te dará detalles importantes y notas sobre cómo proceder.
#
# ### Pasos para avanzar
#
# Para avanzar al siguiente conjunto de tareas, haz clic en el botón **Next (siguiente)**. Este botón se mostrará cuando hayas completado todas las tareas requeridas en esa parte de la actividad. También verás cómo cambia el porcentaje de finalización a medida que trabajas en las tareas.
#
# Antes de empezar, te pedimos que explores los aspectos de la actividad y hagas un poco de planificación. Algunos PTTA pueden abrirse con preguntas de respuesta abierta. Estas preguntas te guían en la exploración de los modos lógicos y físicos en Packet Tracer. Incluso se te puede pedir que predigas lo que crees que sucederá. También se pueden proporcionar respuestas de muestra.
#
# En muchos PTTA, verás estas preguntas abiertas al final de la actividad, dándote la oportunidad de reflexionar sobre lo que hiciste y lo que aprendiste. No olvides hacer clic en **Submit (enviar)** una vez que tus respuestas estén completas.
#
# ### Uso de las sugerencias y la lista de verificación
#
# Cuando estés en la actividad, verás un "checklist" con las tareas. Habrá una marca de verificación verde una vez que hayas completado cada tarea. Puedes hacer clic en el botón **Back (atrás)** en cualquier momento para ir a la pantalla anterior, pero el botón **Next (siguiente)** no estará disponible hasta que hayas completado todas las tareas.
#
# La primera pista está indicada por un signo de interrogación. Las sugerencias se activan según tu nivel elegido:
#
# * **Todas las sugerencias:** recibes todas las pistas disponibles.
# * **Sugerencias críticas:** solo obtienes la pista más esencial.
# * **Más sugerencias:** un nivel intermedio entre los dos anteriores.
# * **Sin sugerencias:** si estás preparado para un desafío.
#
# Las sugerencias no aparecerán de inmediato. Esto te da la oportunidad de pensar en el problema antes de que se te dé una pista que te lleve a la respuesta. Puedes ajustar esta configuración de nivel de sugerencia en cualquier momento durante la actividad.
#
# ### Finalización de la actividad
#
# Una vez que completes los elementos de la lista de verificación, podrás avanzar a la siguiente pantalla y tu porcentaje de finalización aumentará.
#
# Al final de la actividad, serás llevado a la pantalla de resumen. Esta pantalla te recordará las tareas que has completado y te dará un resumen de las preguntas de respuesta abierta. Esto ayuda a reforzar tu aprendizaje.
#
# Ahora que tienes una idea de cómo funcionan las sugerencias de PTTA, prueba la actividad por ti mismo. Recuerda que puedes cambiar los niveles de las pistas en cualquier momento o usar el botón **Reset (reinicio)** para empezar la actividad de nuevo.
#
# ¡Buena suerte con tu primera actividad asistida en Packet Tracer!
#
# ---
#
# # 1.1.5 Video – Usando actividades PTTA - Modelo Lógico y Físico
# El siguiente paso es la actividad con tutoría de Packet Tracer. ¡Aquí hay algunos videos tutoriales que quizás quiera revisar antes de lanzarse!
#
# ### Inspección de dispositivos en modo físico
#
# En el **modo físico** de Cisco Packet Tracer, puedes hacer clic derecho en un dispositivo para abrir un menú. Si está disponible, haz clic en **Inspeccionar el frente** para obtener una vista más amplia. Si quieres acercarte aún más, usa el ícono de la lupa. Esto te permite ver con detalle la numeración y el etiquetado de los puertos.
#
# Algunos dispositivos también te permiten ver la parte trasera. En un conmutador, por ejemplo, puedes inspeccionar el frente para ver los puertos y luego hacer clic derecho para ver la parte trasera, donde a menudo se encuentra el puerto de consola.
#
# ### Uso de la función de inspección al conectar dispositivos
#
# La función de inspección es muy útil cuando estás conectando cables. Por ejemplo, si seleccionas un **cable directo** y haces clic derecho en un enrutador, puedes inspeccionar el frente y hacer zoom para encontrar el puerto que necesitas, como "Fast Ethernet 0/0".
#
# Una vez que tengas el cable conectado a la mitad, ve al otro dispositivo (como un conmutador) y repite el proceso: inspecciona el frente, haz zoom y conecta el cable al puerto correcto, como el "0/24".
#
# ---
#
# # 1.1.6 Actividad supervisada de Packet Tracer - Exploración del modo Lógico y Físico
# En esta actividad supervisada por Packet Tracer, explorará el modo lógico y físico. Esta actividad incluye un sistema de sugerencias y un tutorial incorporado. Se recomienda que vea el vídeo Actividad Supervisada de Packet Tracer antes de realizar esta actividad. También puede acceder a los vídeos tutoriales en la página anterior de este curso.
#
# Nota : Después de abrir este archivo, puede tardar algún tiempo en cargarse.

# %% [markdown]
# # 2.0.1 Tipos de archivos de Cisco Packet Tracer
# Esperamos que haya disfrutado de la actividad asistida de Cisco Packet Tracer en el módulo anterior. En ese PTTA, aprendió a navegar por la interfaz lógica y física, identificar dispositivos y tipos de conexión y cambiar el nombre de un dispositivo. Todas estas son habilidades que necesitará para trabajar en cualquier tipo de actividad de Packet Tracer. Hablando de los tipos de actividades de PT, es importante entender los diferentes tipos de archivos que encontrará al utilizar Cisco Packet Tracer.
#
# Packet Tracer tiene la capacidad de crear cuatro tipos diferentes de archivos. Estos tipos de archivos se utilizan para distintos fines e incluyen: .pka, .pkt, .pksz y .pkz.
#
# # El tipo de archivo .pka
# El tipo de archivo .pka es un archivo de actividad de Packet Tracer y es el tipo de archivo que experimentará con más frecuencia. Piense que la «a» en .pka significa «actividad». Una actividad de Packet Tracer tiene una ventana de instrucciones. Por lo general, la actividad también se puntúa. Este tipo de archivo contiene dos redes: una red inicial y una red de respuesta. La red inicial se abre cuando inicias la actividad. La red de respuestas se ejecuta en segundo plano y se puede utilizar para proporcionar puntuación y comentarios a los alumnos a medida que completan la actividad. Los alumnos no tienen acceso a la red de respuestas en un archivo .pka.
#
# La ventana de instrucciones de la actividad de Packet Tracer proporciona los procedimientos necesarios para completar la actividad, la tarea o la evaluación. La ventana de instrucciones también puede mostrar el porcentaje de finalización para realizar un seguimiento de la cantidad de actividad que se ha completado con éxito. La función Check Results (comprobar resultados) se puede habilitar para proporcionar comentarios.
#
# # El tipo de archivo .pkt
# El tipo de archivo .pkt se crea cuando se crea una red simulada en Packet Tracer y se guarda. El archivo.pkt también puede tener imágenes de fondo gráficas incrustadas en él. Sin embargo, los archivos .pkt no tienen ventana de instrucciones ni puntuación de actividad.
#
# # El tipo de archivo .pksz
# El tipo de archivo .pksz es específico de Actividades asistidas en Packet Tracer (PTTA). Estos archivos incluyen un archivo .pka, recursos multimedia y un archivo de secuencias de comandos para el sistema de sugerencias. Estas actividades brindan apoyo, en forma de sugerencias contextualizadas, para los estudiantes que están trabajando para completar la actividad.
#
# # El tipo de archivo .pkz
# Verá Guardar como PKZ... en el menú Archivo. Este tipo de archivo se utilizaba anteriormente para incrustar imágenes y otros archivos en un archivo de Packet Tracer. Sin embargo, las imágenes ahora se incrustan directamente en un archivo .pkt o .pka normal de forma predeterminada. Por lo tanto, considere .pkz como un tipo de archivo obsoleto.
#
# # 2.0.2 Evaluaciones de Cisco Packet Tracer
# Hay dos tipos de elementos de evaluación que aprovechan Packet Tracer. Estos incluyen Objetos de medios de seguimiento de paquetes (PTMO) y Evaluaciones de habilidades de rastreadores de paquetes (PTSA). Los PTMO pueden ser un archivo.pkt o.pka. Un PTMO aparecerá con una pregunta en su cuestionario, examen de módulo o algún otro tipo de evaluación calificada. Inicie el archivo .pkt o .pka directamente desde dentro de la evaluación. Por lo general, se configura la red o se investiga la topología y, a continuación, se responde a una pregunta o preguntas de evaluación de opción múltiple.
#
# Puede encontrar una evaluación PTSA en un punto intermedio de un curso o al final del curso. Las PTSA son evaluaciones sumativas de habilidades en las que usted demuestra sus habilidades mediante la implementación de las tecnologías que ha aprendido. Las PTSA son evaluaciones independientes, tienen su propio motor de calificación y los resultados se registran en un libro de calificaciones del curso, si lo hay. Después de completar una PTSA, recibirá comentarios a nivel de elemento para cada componente calificado.
#
# Haga clic en Reproducir en el vídeo para obtener más información sobre los archivos PTMO y PTSA Packet Tracer.
#
# # 2.1.1 Vídeo: Usando las actividades.pka
# El siguiente paso es la actividad Crear un rastreador de paquetes de red simple. ¡Aquí hay un par de videos tutoriales que quizás quieras revisar antes de empezar!
#
# Aquí tienes el fragmento de texto sobre cómo determinar direcciones IP en Packet Tracer, convertido a formato Markdown y sin las marcas de tiempo.
#
# ---
#
# ### Bienvenido a Cisco Packet Tracer: Determinar las direcciones IP
#
# En Cisco Packet Tracer, existen varias formas de encontrar la dirección IP de un dispositivo.
#
# **1. A través de la pestaña de Configuración**
#
# Para un dispositivo como una PC, puedes hacer clic en él y seleccionar la pestaña **Configuración**. Desde allí, ve a la interfaz **FastEthernet0**. Aquí verás que el direccionamiento es estático.
#
# * **Dirección IP:** `192.168.1.3`
# * **Máscara de subred:** `255.255.255.0` (te dice las tres primeras partes de la dirección de red)
# * **Puerta de enlace predeterminada:** `192.168.1.1` (la entrada para salir de tu red local)
#
# **2. A través del Símbolo del Sistema**
#
# Otra forma de ver la configuración IP es yendo a la pestaña **Escritorio** y abriendo el **Símbolo del sistema**. Este proceso simula una máquina con Windows.
#
# Escribe `ipconfig` y verás la información detallada: la dirección IPv4, la máscara de subred y la puerta de enlace predeterminada.
#
# ### Direcciones IP con DHCP
#
# Si un dispositivo, como una laptop, ha obtenido su dirección IP a través de un servidor DHCP (Protocolo de Configuración Dinámica de Host), notarás que la información de la dirección en la pestaña de **Configuración** aparece en color gris. Esto indica que fue asignada dinámicamente.
#
# Aunque los campos estén en gris, puedes ver la dirección IP, la máscara de subred y la puerta de enlace predeterminada.
#
# Para confirmarlo, también puedes ir a la pestaña **Escritorio**, abrir el **Símbolo del sistema** y usar el comando `ipconfig` para ver la dirección IP, la máscara de subred y la puerta de enlace predeterminada asignadas por el servidor DHCP.
#
# ---
#
# ¡Disfruta explorando y aprendiendo con Cisco Packet Tracer!
#
#
# # 2.1.2 Packet Tracer: cree una red simple
# En esta actividad de Packet Tracer, completará los siguientes objetivos:
#
# Parte 1: Crear una red simple
# Parte 2: Configurar los dispositivos finales y verificar la conectividad
# ¿No tienes experiencia en redes? ¡No se preocupe! El archivo de instrucciones le proporciona instrucciones paso a paso para completar la actividad. Abra las instrucciones con el botón izquierdo de abajo. Use el botón de la derecha para descargar el archivo de actividad .pka.
#
# # Packet Tracer - Creación de una red simple
# Objetivos
# En esta actividad, creará una red simple en Packet Tracer en el Espacio de trabajo lógico.
#
# Parte 1: Crear una red simple
#
# Parte 2: Configurar los dispositivos finales y verificar la conectividad
#
# Instrucciones
# Parte 1: Construya una red simple
# En esta parte, creará una red simple mediante la implementación y la conexión de los dispositivos de red en el Espacio de trabajo lógico.
#
# Paso 1: Agregue dispositivos de red al espacio de trabajo.
# En este paso, agregará un PC, un portátil y un cable módem al espacio de trabajo lógico.
#
# Un cable módem es un dispositivo de hardware que permite las comunicaciones con un Proveedor de servicios de Internet (ISP). El cable coaxial del ISP está conectado al cable módem y también se conecta un cable Ethernet de la red local. El cable módem convierte la conexión coaxial en una conexión Ethernet.
#
# Mediante el cuadro de Device-Type Selection (selección de Tipo de dispositivo), añada los siguientes dispositivos al espacio de trabajo. La categoría y la subcategoría asociadas al dispositivo se enumeran a continuación:
#
# =   PC: End Devices > End Devices > PC
#
# =   Laptop: End Devices > End Devices > Laptop
#
# =   Cable Modem: Network Devices > WAN Emulation > Cable Modem
#
# Paso 2: Cambie los nombres en pantalla de los dispositivos de red.
# a.    Para cambiar los nombres de los dispositivos de red, haga clic en el icono del dispositivo en el Espacio de trabajo lógico (Logical Workspace).
#
# b.    Haga clic en la ventana de Config en la ventana de configuración del dispositivo.
#
# c.    Ingrese el nuevo nombre del dispositivo recién agregado en el campo Display Name : PC, Laptop, and Cable Modem.
#
# Paso 3: Agregue el cableado físico entre los dispositivos en el espacio de trabajo.
# Con el cuadro de Device-Type Selection (selección de tipo de dispositivos), agregue el cableado físico entre los dispositivos en el espacio de trabajo.
#
# a.    La PC necesita un cable de cobre de conexión directa para conectarse al router inalámbrico. En el cuadro de Device-Type Selection (selección de Tipo de dispositivo), haga clic en Connections (icono de rayo). Seleccione el cable de cobre de conexión de conexión directa en el cuadro de selección de dispositivos, y conéctelo a la interfaz FastEthernet0 de la PC y la interfaz Ethernet 1 del router inalámbrico.
#
# b.     El router inalámbrico necesita un cable de cobre de conexión directa para conectarse al cable módem. Seleccione el cable de cobre de conexión directa en el cuadro de selección de dispositivos, y conéctelo a la interfaz de Internet del router inalámbrico y a la interfaz de Puerto 1 del cable módem.
#
# c.     El cable módem necesita un Cable coaxial para conectarse a la nube de Internet. Seleccione el cable coaxial en el cuadro de selección de dispositivos, y conéctelo a la interfaz de Puerto 0 del cable módem y a la interfaz Coaxial 7 de la nube de Internet.
#
# Parte 2: Configurar los dispositivos finales y verificar la conectividad
# En esta parte, conectará una PC y una computadora portátil al enrutador inalámbrico. La PC se conectará a la red mediante un cable Ethernet. Para la computadora portátil, reemplazará la tarjeta de interfaz de red (NIC) Ethernet con cable por una NIC inalámbrica y conectará la computadora portátil al enrutador de forma inalámbrica.
#
# Una vez que ambos dispositivos finales estén conectados a la red, verificará la conectividad a cisco.srv. A la PC y al portátil se les asignará una dirección IP (Protocolo de Internet). El Protocolo de Internet es un conjunto de reglas para enrutar y direccionar datos en Internet. Las direcciones IP se utilizan para identificar los dispositivos en una red y permitir que los dispositivos se conecten y transfieran datos en una red.
#
# Paso 1: Configure la PC.
# En este paso, configurará el PC para la red cableada.
#
# a.     Haga clic en la PC. En la pestaña Desktop, vaya a IP Configuration para verificar que DHCP esté habilitado y que el equipo haya recibido una dirección IP.
#
# Seleccione DHCP para el encabezado Configuración de IP si no ve una dirección IP para el Campo dirección IPv4. Observe el proceso mientra la PC recibe una dirección IP del servidor DHCP.
#
# DHCP significa protocolo de configuración dinámica de host Este protocolo asigna direcciones IP a los dispositivos de forma dinámica. En esta sencilla red, el enrutador inalámbrico está configurado para asignar direcciones IP a los dispositivos que solicitan direcciones IP. Si DHCP está deshabilitado, deberá asignar una dirección IP y configurar toda la información necesaria para comunicarse con otros dispositivos de la red e Internet.
#
# b.     Cierre la ventana de Configuración IP. En la pestaña Escritorio, haga clic en el Símbolo del sistema.
#
# c.    En el prompt, escriba ipconfig /all para revisar la información de direcciones IPv4 del servidor DHCP. La PC debe recibir una dirección IPv4 en el rango de 192.168.0.x.
#
# Nota: Hay dos tipos de direcciones IP: IPv4 e IPv6. Una dirección IPv4 (protocolo de Internet versión 4) es una cadena de números en forma de x.x.x.x tal como ha estado utilizando en este laboratorio. A medida que crecía Internet, se hizo mayor la necesidad de nuevas direcciones IP. Por lo tanto, IPv6 (protocolo de Internet versión 6) se introdujo a finales de la década de 1990 para abordar las limitaciones de IPv4. Los detalles del direccionamiento IPv6 están fuera del alcance de esta actividad.
#
# d.    Pruebe la conectividad al servidor Cisco.srv en la PC. Desde el símbolo del sistema, emita el comando ping cisco.srv Puede tardar unos minutos para el retorno del ping. Se deben recibir cuatro respuestas, como se muestra en la figura.
#
# Paso 2: Configure la computadora portátil.
# En este paso, configure la computadora portátil para acceder a la red inalámbrica.
#
# a.    Haga clic en Laptop y seleccione la pestaña Physicial (Físico).
#
# b.     En la pestaña Physical , debe quitar el módulo Ethernet de cobre y reemplazarlo por el módulo inalámbrico WPC300N.
#
# 1)    Apague la Laptop haciendo clic en el botón de encendido que se encuentra a un costado de la computadora portátil.
#
# 2)    Quite el módulo de Ethernet de cobre instalado actualmente haciendo clic en el módulo al costado de la computadora portátil, y arrástrelo al panel Módulos a la izquierda de la ventana de la computadora portátil.
#
# 3)   Instale el módulo inalámbrico WPC300N haciendo clic en él en el panel Módulos , y arrástrelo al puerto del módulo vacío al costado de la computadora portátil.
#
# 4)   Vuelva a encender la Laptop haciendo clic en el botón de Laptop Power (encendido de la Computadora portátil).
#
# c.    Con el módulo inalámbrico instalado, conecte la computadora portátil a la red inalámbrica. Haga clic en la pestaña Escritorio y luego haga clic en Computadora inalámbrica.
#
# d.    Seleccione la pestaña Connect (Conectar). Después de un ligero retraso, la red inalámbrica HomeNetwork estará visible en la lista de redes inalámbricas. Si es necesario haga clic en Actualizar para ver la lista de redes disponibles. Seleccione HomeNetwork. Haga clic en Conectar.
#
# e.    Cierra laPC Wireless (PC Inalambrica). Seleccione Navegador web en la pestaña Escritorio.
#
# f.      En el Navegador web, acceda a cisco.srv.
#
# Reflexión
# Ahora que ha verificado la conectividad a cisco.srv, use el comando ipconfig del Command Prompt para completar la tabla de direcciones IP a continuación:
#
# Mostrar respuesta
# Las direcciones IP de los dispositivos finales pueden oscilar entre 192.168.0.2 y 192.168.0.254. Cada adaptador de red (NIC) obtendrá una dirección IP única en la misma red.
#
# La máscara de subred IPv4 (o la longitud del prefijo) se usa para diferenciar la porción de red de la porción de host de una dirección IPv4. Puede relacionar la dirección IP con la dirección de su calle. La máscara de subred define la longitud del nombre de la calle. La parte de la red de la dirección es su calle, 192.168.0. El número de casa es el puerto de host de la dirección IP. Para la dirección IP 192.168.0.2, el número de casa es el 2 y la calle es 192.168.0. Si hay más de una casa en la misma calle, por ejemplo, la casa número 3, tendrá una dirección 192.168.0.3. El número máximo de casas en esta calle es de 253, que varía entre 2 y 254.
#
# La puerta de enlace predeterminada es análoga a la entrada de una calle. El tráfico de la calle 192.168.0 tiene que salir a través de la intersección con otra calle. Otra calle es otra red. En esta red, la puerta de enlace predeterminada es el enrutador inalámbrico que dirige el tráfico desde la red local al cable módem y, a continuación, el tráfico se envía al ISP.
#
#
#
# # 2.1.3 Vídeo: funciones avanzadas de Cisco Packet Tracer
# Aquí tienes el fragmento de texto sobre cómo personalizar los fondos en Packet Tracer, convertido a formato Markdown y sin las marcas de tiempo.
#
# ---
#
# ### Bienvenido a Cisco Packet Tracer: Personaliza los fondos
#
# **Cisco Packet Tracer** te permite añadir imágenes de fondo a tu espacio de trabajo.
#
# Para hacerlo, haz clic en el icono en la parte superior derecha, llamado **Establecer imagen de fondo**. Puedes navegar a través de las imágenes integradas en Packet Tracer. Por ejemplo, si seleccionas un esquema de un edificio o un piso, puedes aplicarlo a tu espacio de trabajo y alejar la imagen para verla completa.
#
# También tienes la opción de añadir imágenes personalizadas. Vuelve al mismo icono, haz clic en **Examinar** y selecciona una imagen que hayas descargado, como un mapa de un campus o de una ciudad. Al aplicarlo, puedes mover tus dispositivos, como los enrutadores, para que se ubiquen en las áreas correspondientes en el mapa.
#
# ---
#
# Disfruta explorando y aprendiendo con Cisco Packet Tracer.
#
# Para saber cómo usar diferentes fondos en tu espacio de trabajo, mira este video sobre [fondos para espacio de trabajo, dispositivos y página Web en Packet Tracer](https://www.youtube.com/watch?v=ZDHQJKj5o_s).
# http://googleusercontent.com/youtube_content/6
