# %% [markdown]
# # 📄 README.md para el Proyecto: Telecom X – Análisis de Evasión de Clientes
# A continuación te paso una plantilla completa y editable que podés copiar en un archivo llamado README.md en la raíz de tu proyecto:
#
# # 📊 Telecom X – Análisis de Evasión de Clientes (Churn)
#
# Este proyecto fue desarrollado como parte del desafío final del programa de Data Science.
# El objetivo es analizar el fenómeno de *churn* (evasión de clientes) para la empresa ficticia **Telecom X**, utilizando datos reales en formato JSON, transformándolos, analizándolos y extrayendo información clave para la toma de decisiones.
#
# ---
#
# ## 🚀 Objetivos del Proyecto
#
# - Importar y manipular datos desde una API/archivo JSON.
# - Aplicar conceptos de **ETL** (Extracción, Transformación y Carga).
# - Realizar un **Análisis Exploratorio de Datos (EDA)**.
# - Visualizar patrones que expliquen la evasión de clientes.
# - Generar un informe con **insights** y **recomendaciones estratégicas**.
#
# ---
#
# ## 🧠 Tecnologías Utilizadas
#
# - Python 3.x
# - Jupyter Notebook
# - Bibliotecas:
#   - `pandas`
#   - `numpy`
#   - `matplotlib`
#   - `seaborn`
#   - `json`
#
# ---
#
# ## 📁 Estructura del Proyecto
#
#
# ---
#
# ## 🔍 Análisis Realizado
#
# - **Limpieza**: desanidado de estructuras JSON, tratamiento de valores nulos y duplicados.
# - **Transformación**: conversión de columnas categóricas (Sí/No → 1/0), creación de nuevas variables (`Cuentas_Diarias`).
# - **Visualización**: gráficos de barras, pie charts y boxplots para identificar patrones.
# - **Insights**:
#   - El *churn* es más frecuente en clientes con contratos mensuales.
#   - Clientes con menor tiempo de permanencia y menor facturación tienden a cancelar.
#   - El método de pago electrónico está correlacionado con una mayor tasa de cancelación.
#
# ---
#
# ## 📌 Conclusiones
#
# Este análisis permite identificar factores clave detrás de la evasión de clientes.
# Los hallazgos pueden ser utilizados por el equipo de marketing o fidelización para diseñar estrategias de retención más efectivas.
#
# ---
#
# ## 💡 Recomendaciones
#
# - Implementar beneficios para clientes con contrato mensual que estén por cancelar.
# - Incentivar la migración a contratos anuales con descuentos o beneficios exclusivos.
# - Realizar campañas dirigidas a usuarios con bajo tenure o bajo consumo mensual.
#
# ---
#
# ## 📫 Contacto
#
# Desarrollado por **Pablo Monsalvo**
# 📧 ![Buscotrabajo87@outlook.com](/home/pol/Escritorio/ipynb-alura/assets/telecomx-7.png)
#
# ---

# %% [markdown]
# # Alumno: Pablo Matías Monsalvo G8-ONE 12/07/2025

# %% [markdown]
# ## 03 Importancia del desafio
#  Siguiente pregunta
#
# ### Desafío Telecom X
# El desafío Telecom X ofrece una oportunidad única para aplicar habilidades esenciales de análisis de datos en un escenario de negocios real.
#
# ### Aplicación práctica del conocimiento
# La limpieza y tratamiento de datos es una habilidad fundamental para cualquier analista de datos. La manipulación de grandes volúmenes de información exige la capacidad de identificar y corregir inconsistencias en los datos, como valores nulos, duplicados y datos fuera de estándar. Garantizar que los datos estén listos para el análisis es un paso esencial para obtener resultados precisos y confiables.
#
# El análisis exploratorio de datos (EDA) es una etapa crucial para comprender en profundidad los datos. La capacidad de aplicar estadísticas descriptivas y generar visualizaciones permite identificar patrones, tendencias y relaciones entre las variables. Esto ayuda a formular hipótesis y generar insights que pueden influir en decisiones estratégicas dentro de la empresa.
#
# Al participar en este desafío, aplicarás conocimientos esenciales para el análisis de grandes volúmenes de datos en un contexto real, donde tus hallazgos podrán impactar directamente en las estrategias de la empresa para mejorar el principal problema que están enfrentando.
#
# Este desafío no solo contribuye a tu crecimiento en el área de Data Science, sino que también ofrece la oportunidad de entender cómo la ciencia de datos puede aplicarse para resolver problemas reales que enfrentan las empresas en el mercado.

# %% [markdown]
# -----

# %% [markdown]
# # ✅ Prompt 2 – Cargar JSON en un DataFrame con pandas
#
# """
# 1. Cargá datos desde un archivo JSON llamado 'TelecomX_Data.json' usando pandas.
# 2. Convertí los datos a un DataFrame y mostrá las primeras 5 filas.
# 3. Asegurate de que el archivo esté en la ruta correcta: '../data/TelecomX_Data.json'.
# """

# %%
import pandas as pd
import json

# Ruta al archivo local
ruta_archivo = '../data/TelecomX_Data.json'

# Cargar el archivo JSON
with open(ruta_archivo, 'r') as f:
    datos_json = json.load(f)

# Convertir a DataFrame
df = pd.DataFrame(datos_json)

# Mostrar las primeras filas
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ## 🔍 Siguiente paso: Prompt 3 – Explorar estructura y tipos de columnas
# ### ✅ Prompt 3
# """
# Explorá la estructura del DataFrame:
# 1. Usá .info() para ver nombres de columnas y tipos de datos.
# 2. Usá .dtypes para confirmar los tipos individuales.
# 3. Identificá qué columnas están anidadas (es decir, contienen diccionarios) y serán necesarias desanidar para el análisis.
# """

# %%
# Ver estructura general
df.info()

# Tipos de datos
print("\nTipos de datos por columna:")
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB
#
# Tipos de datos por columna:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %% [markdown]
# ¡Perfecto, Pablo! 🔍 Ya tenemos el diagnóstico:
#
# ✅ Lo que aprendimos:
# El DataFrame tiene 7267 filas y 6 columnas.
#
# Todas las columnas son de tipo object, pero customer, phone, internet y account contienen diccionarios anidados.
#
# Para poder analizarlas, hay que desanidarlas ("flatten") en columnas individuales.
#
# 🔧 Siguiente paso: Prompt 4 – Detectar problemas de calidad en los datos
# Antes de desanidar, verificamos si hay valores nulos o duplicados en el nivel principal. Luego, pasamos al flatten.

# %% [markdown]
# """
# Analizá la calidad inicial del DataFrame:
# 1. ¿Existen valores nulos? Usá .isnull().sum()
# 2. ¿Existen filas duplicadas? Usá .duplicated().sum()
# 3. Mostrá los valores únicos de la columna 'Churn' para asegurarte de que estén correctamente escritos.
# """

# %%
# 1. Verificar valores nulos
print("Valores nulos por columna:")
print(df.isnull().sum())

# 2. Verificar duplicados SOLO con columnas hashables
print("\nCantidad de filas duplicadas en columnas simples:")
print(df[['customerID', 'Churn']].duplicated().sum())

# 3. Valores únicos de Churn
print("\nValores únicos en la columna 'Churn':")
print(df['Churn'].unique())
# Out:
# Valores nulos por columna:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64
#
# Cantidad de filas duplicadas en columnas simples:
# 0
#
# Valores únicos en la columna 'Churn':
# ['No' 'Yes' '']

# %% [markdown]
# ¡Excelente trabajo, Pablo! 🧠👏
# Ya tenemos un panorama muy claro del estado actual del dataset:
#
# ✅ Diagnóstico del paso 4:
# Revisión	Resultado
# Valores nulos	❌ Ninguno
# Filas duplicadas (básicas)	❌ Ninguna
# Valores en columna Churn	✅ 'Yes', 'No', ⚠️ '' (cadena vacía)
#
# ⚠️ Observación:
# El valor '' (cadena vacía) en la columna Churn probablemente debería considerarse como valor nulo (NaN), ya que no representa una respuesta válida.

# %% [markdown]
# ## 🔧 Paso 5: Desanidar columnas y corregir inconsistencias
# ### ✅ Prompt 5
#
# """
# Desanidá las columnas 'customer', 'phone', 'internet' y 'account', que contienen diccionarios.
# Convertí cada clave de esos diccionarios en nuevas columnas.
# Luego, corregí la columna 'Churn' reemplazando los valores vacíos ('') por NaN.
# """

# %%
# Importar numpy para usar NaN
import numpy as np

# 1. Expandir columnas anidadas
df_customer = pd.json_normalize(df['customer'])
df_phone = pd.json_normalize(df['phone'])
df_internet = pd.json_normalize(df['internet'])
df_account = pd.json_normalize(df['account'])

# 2. Unir todo en un solo DataFrame plano
df_final = pd.concat([df[['customerID', 'Churn']], df_customer, df_phone, df_internet, df_account], axis=1)

# 3. Reemplazar valores vacíos en Churn por NaN
df_final['Churn'] = df_final['Churn'].replace('', np.nan)

# Verificar el resultado
df_final.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %% [markdown]
# ¡Excelente, Pablo! Ahora sí, el DataFrame está perfectamente desanidado 🎯
# Te felicito, hiciste una de las etapas más técnicas del proceso de ETL como un profesional 💪
#
# 🧾 Estado actual (resumen):
# ✅ JSON cargado correctamente
#
# ✅ Diccionarios desanidados (customer, phone, internet, account)
#
# ✅ df_final tiene columnas limpias como gender, tenure, InternetService, Contract, Charges.Monthly, etc.
#
# ✅ Reemplazamos valores vacíos en Churn por NaN

# %% [markdown]
# ## 🔢 Siguiente paso: Prompt 6 – Crear columna Cuentas_Diarias
# La idea es calcular cuánto paga un cliente por día, a partir de la columna Charges.Monthly.
#
# ### ✅ Prompt 6
#
# """
# Crea una nueva columna llamada 'Cuentas_Diarias' dividiendo la columna 'Charges.Monthly' entre 30.
#
# Esta columna representa el gasto diario estimado de cada cliente y será útil para análisis más detallados.
# """

# %%
# Asegurarse de que 'Charges.Monthly' sea numérica (por si acaso)
df_final['Charges.Monthly'] = pd.to_numeric(df_final['Charges.Monthly'], errors='coerce')

# Crear columna de cuentas diarias
df_final['Cuentas_Diarias'] = df_final['Charges.Monthly'] / 30

# Mostrar algunas filas para verificar
df_final[['customerID', 'Charges.Monthly', 'Cuentas_Diarias']].head()
# Out:
#    customerID  Charges.Monthly  Cuentas_Diarias
# 0  0002-ORFBO             65.6         2.186667
# 1  0003-MKNFE             59.9         1.996667
# 2  0004-TLHLJ             73.9         2.463333
# 3  0011-IGKFF             98.0         3.266667
# 4  0013-EXCHZ             83.9         2.796667

# %% [markdown]
# ¡Perfecto, Pablo! 🙌
# Ya calculamos exitosamente la columna Cuentas_Diarias. Ahora tenés una métrica diaria precisa que puede revelar patrones sutiles de comportamiento financiero del cliente.
#
# ## 🔁 Seguimos con: Prompt 7 – Transformar y estandarizar datos
# Objetivo:
# Convertir valores 'Yes'/'No' en 1 y 0 para facilitar el análisis.
#
# Opcionalmente, renombrar columnas si tienen espacios o caracteres raros.
#
# ### ✅ Prompt 7
#
# """
# Transformá los valores 'Yes' y 'No' en 1 y 0 en todas las columnas relevantes del DataFrame.
# Además, si hay columnas con espacios o caracteres especiales, renombralas usando snake_case (guion bajo).
# """

# %%
# 1. Reemplazar 'Yes'/'No' por 1/0 en todas las columnas categóricas
df_final.replace({'Yes': 1, 'No': 0}, inplace=True)

# 2. Renombrar columnas con espacios o caracteres raros (opcional pero buena práctica)
df_final.columns = df_final.columns.str.strip().str.replace(' ', '_').str.replace('.', '_')

# Verificar algunas columnas
df_final[['Partner', 'Dependents', 'PaperlessBilling', 'StreamingTV', 'Contract']].head()
# Out:
# /tmp/ipykernel_19393/3867671674.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_final.columns = df_final.columns.str.strip().str.replace(' ', '_').str.replace('.', '_')
#    Partner  Dependents  PaperlessBilling StreamingTV        Contract
# 0        1           1                 1           1        One year
# 1        0           0                 0           0  Month-to-month
# 2        0           0                 1           0  Month-to-month
# 3        1           0                 1           1  Month-to-month
# 4        1           0                 1           1  Month-to-month

# %% [markdown]
# ¡Perfecto, Pablo! Los valores booleanos ya están numéricos (1 y 0) y las columnas están limpias, solo Contract sigue en texto (que está bien porque es categórica con más de dos niveles).
#
# ## 🔄 Próximo paso: Prompt 8 – Análisis descriptivo estadístico
# Objetivo:
# Obtener estadísticas descriptivas básicas de las variables numéricas.
#
# Entender la distribución, tendencia central y dispersión.
#
# ### ✅ Prompt 8
#
# """
# Realizá un análisis descriptivo usando pandas .describe() para todas las columnas numéricas.
# Interpretá la media, desviación estándar, valores mínimos y máximos para entender mejor la distribución de los datos.
# """

# %%
# Estadísticas descriptivas solo de columnas numéricas
estadisticas = df_final.describe()

print(estadisticas)
# Out:
#              Churn  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7267.000000  7267.000000  7267.000000  7267.000000
# mean      0.265370       0.162653     0.484106     0.300124    32.346498
# std       0.441561       0.369074     0.499782     0.458343    24.571773
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       0.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  PaperlessBilling  Charges_Monthly  Cuentas_Diarias
# count   7267.000000       7267.000000      7267.000000      7267.000000
# mean       0.902711          0.593230        64.720098         2.157337
# std        0.296371          0.491265        30.129572         1.004319
# ...

# %% [markdown]
# Muy buen avance, Pablo! 🎯
#
# Ese resumen confirma que:
#
# La columna Churn tiene ~26.5% de clientes que cancelaron (promedio = 0.265), es decir, ~1 de cada 4.
#
# Tenemos 7.267 registros, pero Churn tiene 7.043 valores no nulos (faltan datos para algunos clientes).
#
# Variables como SeniorCitizen, Partner, Dependents están codificadas como 0 y 1, perfecto.
#
# tenure promedio es 32 meses, que representa tiempo de permanencia.

# %% [markdown]
# ## Siguiente paso: Prompt 9 – Visualizar distribución de churn
# Objetivo:
# Crear un gráfico de barras o pie que muestre la proporción de clientes que permanecieron y los que cancelaron.
#
# ### ✅ Prompt 9
#
# """
# Visualizá la distribución de la variable 'Churn' con un gráfico de barras o un pie chart usando seaborn o matplotlib.
#
# Mostrá claramente la proporción de clientes que cancelaron (1) y los que no (0).
# """

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Contar valores de churn (excluir NaN)
churn_counts = df_final['Churn'].dropna().value_counts()

# Gráfico de barras
plt.figure(figsize=(6,4))
sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='pastel')
plt.title('Distribución de Churn (evasión de clientes)')
plt.xlabel('Churn (0=No, 1=Sí)')
plt.ylabel('Cantidad de clientes')
plt.show()
# Out:
# /tmp/ipykernel_19393/3353181987.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='pastel')

# %% [markdown]
# ¡Genial, Pablo! Vamos al siguiente paso:
#
# ## 🔎 Prompt 10 – Análisis de churn según variables categóricas
# Objetivo:
# Explorar cómo se distribuye el churn según variables como:
#
# Género (gender)
#
# Tipo de contrato (Contract)
#
# Método de pago (PaymentMethod)
#
# y visualizarlo con gráficos de barras para detectar patrones.
#
# ### ✅ Prompt 10
#
# """
# Para cada variable categórica seleccionada, creá gráficos de barras que muestren la proporción de churn (evasión) para cada categoría.
#
# Variables a analizar: 'gender', 'Contract', 'PaymentMethod'
#
# Mostrá la tasa de churn dentro de cada categoría para detectar qué grupos tienen mayor evasión.
# """

# %%
# Variables categóricas a analizar
categoricas = ['gender', 'Contract', 'PaymentMethod']

import matplotlib.pyplot as plt
import seaborn as sns

for var in categoricas:
    plt.figure(figsize=(8,5))
    sns.barplot(x=var, y='Churn', data=df_final, ci=None, palette='muted')
    plt.title(f'Tasa de churn según {var}')
    plt.ylabel('Tasa de churn (promedio)')
    plt.xlabel(var)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipykernel_19393/897022073.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=var, y='Churn', data=df_final, ci=None, palette='muted')
# /tmp/ipykernel_19393/897022073.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=var, y='Churn', data=df_final, ci=None, palette='muted')
# /tmp/ipykernel_19393/897022073.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=var, y='Churn', data=df_final, ci=None, palette='muted')
# /tmp/ipykernel_19393/897022073.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ChatGPT Plus
# ¡Excelente, Pablo! Me alegra que te guste cómo va quedando.
#
# Ahora seguimos con:
# ## 🔢 Prompt 11 – Análisis de churn con variables numéricas
# Objetivo:
# Explorar la distribución de churn en variables numéricas importantes, como:
#
# Charges_Total (gasto total)
#
# tenure (tiempo de permanencia)
#
# Utilizaremos boxplots para comparar estas variables entre clientes que cancelaron (churn=1) y los que no (churn=0).
#
# ### ✅ Prompt 11
#
# """
# Crea boxplots para comparar la distribución de las variables numéricas 'Charges_Total' y 'tenure' entre los clientes que cancelaron y los que permanecieron.
#
# Esto ayudará a visualizar si existen diferencias notables en estas métricas entre ambos grupos.
# """

# %%
import matplotlib.pyplot as plt
import seaborn as sns

variables_numericas = ['Charges_Total', 'tenure']

for var in variables_numericas:
    plt.figure(figsize=(8,5))
    sns.boxplot(x='Churn', y=var, data=df_final)
    plt.title(f'Distribución de {var} según churn')
    plt.xlabel('Churn (0=No, 1=Sí)')
    plt.ylabel(var)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 for var in variables_numericas:
#       7     plt.figure(figsize=(8,5))
# ----> 8     sns.boxplot(x='Churn', y=var, data=df_final)
#       9     plt.title(f'Distribución de {var} según churn')
#      10     plt.xlabel('Churn (0=No, 1=Sí)')
#
# NameError: name 'df_final' is not defined

# %%
# Paso 0: Importar librerías
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 1: Cargar JSON desde archivo
with open('../data/TelecomX_Data.json', 'r') as f:
    datos_json = json.load(f)

df = pd.DataFrame(datos_json)

# Paso 2: Desanidar columnas
df_customer = pd.json_normalize(df['customer'])
df_phone = pd.json_normalize(df['phone'])
df_internet = pd.json_normalize(df['internet'])
df_account = pd.json_normalize(df['account'])

df_final = pd.concat([df[['customerID', 'Churn']], df_customer, df_phone, df_internet, df_account], axis=1)

# Paso 3: Limpieza básica
df_final['Churn'] = df_final['Churn'].replace('', np.nan)

# Paso 4: Renombrar columnas con puntos o espacios
df_final.columns = df_final.columns.str.strip().str.replace(' ', '_').str.replace('.', '_')

# Paso 5: Conversión a numérico
df_final['Charges_Monthly'] = pd.to_numeric(df_final['Charges_Monthly'], errors='coerce')
df_final['Charges_Total'] = pd.to_numeric(df_final['Charges_Total'], errors='coerce')
df_final['tenure'] = pd.to_numeric(df_final['tenure'], errors='coerce')

# Paso 6: Crear columna diaria
df_final['Cuentas_Diarias'] = df_final['Charges_Monthly'] / 30

# Paso 7: Reemplazar Yes/No
df_final.replace({'Yes': 1, 'No': 0}, inplace=True)
# Out:
# /tmp/ipykernel_34528/4086152189.py:26: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_final.columns = df_final.columns.str.strip().str.replace(' ', '_').str.replace('.', '_')

# %%
variables_numericas = ['Charges_Total', 'tenure']

for var in variables_numericas:
    plt.figure(figsize=(8,5))
    sns.boxplot(x='Churn', y=var, data=df_final)
    plt.title(f'Distribución de {var} según churn')
    plt.xlabel('Churn (0=No, 1=Sí)')
    plt.ylabel(var)
    plt.show()

# %% [markdown]
# ## ¡Excelente, Pablo! 🎉 ¡Estás haciendo un trabajo impecable!
#
# Ya tenés todo lo necesario para avanzar al paso final obligatorio del challenge:
#
# ## 📘 Prompt 12 – Informe final en el notebook
# Objetivo:
# Redactar un informe completo y ordenado dentro del mismo Jupyter Notebook, que incluya texto explicativo y los análisis realizados.
#
# ### ✅ Prompt 12
#
# """
# Redactá un informe en celdas Markdown dentro del mismo notebook que contenga:
#
# 1. Introducción: contexto del problema (evasión de clientes en Telecom X).
# 2. Limpieza y Tratamiento de Datos: resumen del proceso ETL, incluyendo desanidado, valores nulos, y transformación.
# 3. Análisis Exploratorio de Datos (EDA): gráficos, observaciones y patrones descubiertos.
# 4. Conclusiones e Insights: interpretación final, como por ejemplo qué factores están más asociados al churn.
# 5. Recomendaciones: sugerencias al equipo para reducir la evasión.
#
# Usá títulos y subtítulos Markdown (`#`, `##`, `###`) y gráficos donde sea necesario.
# """

# %% [markdown]
# # Informe Final – Análisis de Evasión de Clientes en Telecom X
#
# ## 1. Introducción
# El presente informe analiza la evasión de clientes (churn) en la empresa Telecom X. El objetivo es identificar patrones que expliquen por qué ciertos clientes cancelan el servicio y ayudar a mitigar esta pérdida.
#
# ## 2. Limpieza y Tratamiento de Datos
# - Se cargaron datos desde un archivo JSON.
# - Se desanidaron campos complejos (customer, phone, internet, account).
# - Se detectaron y reemplazaron valores faltantes (`Churn = ''` → NaN).
# - Se estandarizaron variables categóricas (`Yes`/`No` → 1/0).
# - Se creó la variable `Cuentas_Diarias`.
#
# ## 3. Análisis Exploratorio de Datos
# - Tasa de churn: ~26.5%.
# - El churn es más común en clientes con contrato mes a mes y métodos de pago electrónicos.
# - Clientes con menor tiempo de permanencia y menores gastos totales tienden a cancelar.
#
# *Insertar gráficos de barras, boxplots y pie charts*
#
# ## 4. Conclusiones e Insights
# - La modalidad de contrato y el método de pago tienen fuerte relación con la evasión.
# - Usuarios con menor antigüedad y bajo gasto son más propensos a dejar el servicio.
#
# ## 5. Recomendaciones
# - Ofrecer incentivos a nuevos clientes para aumentar su permanencia.
# - Mejorar beneficios para contratos anuales.
# - Supervisar clientes con baja facturación y contactar preventivamente.
