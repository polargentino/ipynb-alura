# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2061-pandas-conociendo-la-biblioteca/blob/proyecto-final/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas: Conociendo la biblioteca**
# ## **Alumno: Pablo Matías Monsalvo G8-ONE**
#
# # 04 Para saber más: la biblioteca Pandas
# Pandas es una biblioteca de código abierto en Python utilizada para el análisis de datos. Proporciona herramientas poderosas y fáciles de usar para la manipulación y análisis de datos en formatos de tablas, como CSV, Excel, SQL y muchos otros.
#
# Con Pandas, podemos cargar datos desde diversas fuentes en un objeto llamado DataFrame, que es una tabla de datos similar a una hoja de cálculo de Excel. Luego, podemos trabajar con estos datos realizando operaciones como filtrar, ordenar, agregar y transformar.
#
# La biblioteca Pandas es ampliamente utilizada en aplicaciones de ciencia de datos, aprendizaje automático, finanzas y análisis empresarial. Es una herramienta esencial para profesionales que trabajan con datos, como analistas de datos, científicos de datos e ingenieros de datos.
#
# En resumen, la biblioteca Pandas es una herramienta de alto rendimiento para el análisis de datos en Python, que permite trabajar con datos en diferentes formatos y realizar diversas operaciones para manipular, analizar y visualizar los datos de manera eficiente y productiva.

# %% [markdown]
# ## **Importando la base de datos**

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url) # online


# cd ~/Escritoriio/ipynb-alura/data
# wget https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
import pandas as pd
df = pd.read_csv('../data/alquiler.csv') # local

# %%
df
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
df_1 = pd.read_csv('../data/alquiler.csv', sep=';') # elimino las punto y coma

# %%
df_1
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df.shape # tamaño de DataFrame
# Out:
# (25121, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 1 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto  25121 non-null  object
# dtypes: object(1)
# memory usage: 196.4+ KB

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df.sample(10) # aleatorias
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 14697  Departamento;Lomas de Chapultepec;4;1;2;220;27...
# 24461  Conjunto Comercial/Sala;Santa Fe;0;1;0;33;5600...
# 22824      Departamento;Nativitas;1;0;0;39;4200.0;700.0;
# 8127   Departamento;Coyoacán;4;2;4;370;105000.0;19974...
# 7371                 Casa;La Florida;4;5;2;165;16450.0;;
# 20308  Departamento;Condesa;4;1;1;160;11550.0;5950.0;...
# 22266  Departamento;Lomas de Chapultepec;4;1;1;140;27...
# 17258  Departamento;Bosques de las Lomas;4;1;2;123;18...
# 12263  Departamento;San Miguel Chapultepec;3;1;0;98;6...
# 20957      Departamento;Arboledas;2;0;0;50;3500.0;;126.0

# %%
df_1.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 24956             Departamento              Santa Fe             2        1
# 24386  Conjunto Comercial/Sala              Santa Fe             0        1
# 19436  Conjunto Comercial/Sala              Santa Fe             0        1
# 18478             Departamento              Santa Fe             3        1
# 22930             Departamento            La Condesa             1        0
# 10959  Conjunto Comercial/Sala      Centro Histórico             0        0
# 10603             Departamento              Coyoacán             2        1
# 16039             Departamento  Lomas de Chapultepec             3        2
# 152               Departamento               Condesa             3        1
# 9821   Conjunto Comercial/Sala      Centro Histórico             0        5
#
#        Suites  Area    Valor  Condominio  Impuesto
# 24956       1    90   7000.0      6300.0    8162.0
# ...

# %%
df.head()
# Out:
#   Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0      Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                   Casa;Polanco;2;0;1;100;24500.0;;
# 2  Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3  Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4      Departamento;Del Valle;1;0;0;48;2800.0;805.0;

# %%
df_1.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Para saber más: diferentes formatos de datos
# Pandas ofrece diversas funciones para importar y exportar datos en diferentes formatos. Las principales funciones de Pandas para importar datos son las siguientes:
#
# read_csv(): Esta función se utiliza para leer archivos CSV (Comma Separated Values), que son archivos de texto que contienen datos separados por comas. Es posible proporcionar varios parámetros para personalizar la lectura del CSV, como el delimitador, el encabezado, el tipo de codificación, entre otros.
#
# read_excel(): Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
#
# read_json(): Esta función se utiliza para leer archivos JSON (JavaScript Object Notation), que son archivos de texto que contienen datos en formato de objeto JavaScript.
#
# read_html(): Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
#
# read_sql(): Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server. Pandas es capaz de importar datos de diferentes maneras, lo que permite ajustar parámetros como la consulta, el nombre de la tabla y el tipo de datos de las columnas.

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 13501             Departamento  Bosques de las Lomas             4        3
# 24195  Conjunto Comercial/Sala                  Roma             0        0
# 6611              Departamento              Narvarte             3        1
# 19004  Conjunto Comercial/Sala      Centro Histórico             0        0
# 8976   Conjunto Comercial/Sala      Centro Histórico             0        0
# 22616    Departamento en Hotel               Condesa             2        2
# 23243             Tienda/Salón      Centro Histórico             0        0
# 23788             Departamento                  Roma             1        1
# 13484             Departamento              Santa Fe             1        1
# 4867              Departamento                Juárez             2        1
#
#        Suites  Area     Valor  Condominio  Impuesto
# 13501       4   190   87150.0     12985.0       NaN
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### **07 - Caracteristicas de los datos**
# ## **Exploración inicial de los datos**

# %%
df_1.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 20963             Departamento         Del Valle             3        1
# 5024   Conjunto Comercial/Sala  Centro Histórico             0        0
# 23291             Departamento          Narvarte             2        1
# 20668             Departamento        La Florida             2        1
# 11963             Departamento          Santa Fe             1        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 20963       0   150  14700.0      3500.0      84.0
# 5024        0    75   9100.0      8456.0     700.0
# 23291       0    76   8750.0      2534.0       NaN
# 20668       0    77   4900.0      1680.0     444.5
# 11963       0    64   5600.0      3360.0     630.0

# %%
datos.sample(5)
# Out:
#                           Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 1548   Conjunto Comercial/Sala      Roma             0       34       0  1482
# 16639             Departamento   Condesa             2        2       1   100
# 3228              Departamento  Narvarte             3        1       1   145
# 9566                      Casa  Santa Fe             5        2       4   622
# 16707    Departamento en Hotel  Santa Fe             1        1       0    70
#
#           Valor  Condominio  Impuesto
# 1548   700245.0    194512.5       NaN
# 16639   11900.0      2555.0     644.0
# 3228     9800.0      3500.0     672.0
# 9566    35000.0      3951.5       NaN
# 16707   15750.0      6475.0    1365.0

# %%
df.shape
# Out:
# (25121, 1)

# %%
df_1.shape
# Out:
# (25121, 9)

# %%
datos.shape
# Out:
# (25121, 9)

# %%
import pandas as pd

# Cargando el archivo local recién descargado
df = pd.read_csv('../data/alquiler.csv', sep=';')

# Verificando la forma del DataFrame
print(df.shape)

# Mostrando las primeras filas
df.head()
# Out:
# (25121, 9)
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
df_1.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
df_1['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones','Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %%
df_1[['Suites','Impuesto']]
# Out:
#        Suites  Impuesto
# 0           0     210.0
# 1           1       NaN
# 2           0    3888.5
# 3           0      70.0
# 4           0       NaN
# ...       ...       ...
# 25116       0       NaN
# 25117       0      87.5
# 25118       0     129.5
# 25119       0       NaN
# 25120       0    3881.5
#
# [25121 rows x 2 columns]

# %% [markdown]
# # 08 - Estructura de datos de Pandas
# La biblioteca Pandas es una de las herramientas más utilizadas por los científicos de datos para el análisis y manipulación de datos. Proporciona dos estructuras de datos principales, el DataFrame y la Serie, que se utilizan ampliamente para representar y manipular datos tabulares en Python.
#
# ¿Cuáles de las siguientes opciones presentan las definiciones correctas de las estructuras de datos DataFrame y Serie?
#
# El DataFrame es una tabla de datos bidimensional, similar a una hoja de cálculo de Excel, con columnas etiquetadas y filas numeradas.
#
#
# Excelente, un DataFrame es básicamente una estructura de datos bidimensional que se utiliza para almacenar información estructurada en forma de tabla.

# %% [markdown]
# # 09 Desafío: vamos a practicar
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos análisis utilizando un archivo CSV diferente: alumnos.csv.
#
# Importa el archivo alumnos.csv y almacena su contenido en un DataFrame de Pandas.
#
# Visualiza las primeras 7 filas del DataFrame y las últimas 5.
#
# Verifica la cantidad de filas y columnas en este DataFrame.
#
# Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
#
# Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.
#
# wget https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv
#
#
# Nombre,Edad,Nota,Aprobado
# Alberto,20,7.5,True
# Ana,18,,False
# Camila,27,2.5,False
# David,18,5.0,False
# Brian,21,10.0,True
# Bruna,23,,False
# Daniela,21,7.0,True
# Carlos,19,6.0,False
# Alicia,35,5.6,False
# Victor,28,,False
# Danilo,21,,False
# Ignacio,24,4.5,False
# Stephany,26,10.0,True
# Miriam,25,9.0,True
# Pablo,37,,False
# Milena,29,7.0,True
# Lucas,33,,False
# Nadia,34,8.0,Verdadero
#
# # Opinión del instructor
#
# ¿Listo para enfrentar estos desafíos?
#
# Es importante destacar que en algunas situaciones podemos utilizar diferentes métodos de Pandas para lograr lo mismo. Por lo tanto, las soluciones a continuación no son la única forma de abordar los desafíos planteados.
#
# Para importar el archivo en cuestión y guardarlo en un DataFrame, podemos importar la biblioteca Pandas y utilizar la función read_csv() pasando la URL donde se encuentra el archivo:

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos_2 = pd.read_csv(url)

# %% [markdown]
# Cuando queremos ver las primeras y últimas filas de un DataFrame, podemos utilizar los métodos head y tail:

# %%
datos_2.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos_2.tail()
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %% [markdown]
# Tanto el atributo shape como el método info nos proporcionan la cantidad de filas y columnas en un DataFrame. El info también muestra información adicional, por lo que utilizaremos shape aquí:

# %%
datos_2.shape
# Out:
# (18, 4)

# %% [markdown]
# En este momento, podemos usar .columns para ver las columnas presentes en el DataFrame. Además, también podemos seleccionar columnas específicas utilizando corchetes "[]". Para ver los tipos de datos en cada columna, esta vez opté por utilizar un atributo llamado dtypes:

# %%
# Visualizar los nombres de las columnas
datos_2.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
# Seleccionar una columna
datos_2['Nombre']
# Out:
# 0      Alberto
# 1          Ana
# 2       Camila
# 3        David
# 4        Brian
# 5        Bruna
# 6      Daniela
# 7       Carlos
# 8       Alicia
# 9       Victor
# 10      Danilo
# 11     Ignacio
# 12    Stephany
# 13      Miriam
# 14       Pablo
# 15      Milena
# 16       Lucas
# 17       Nadia
# Name: Nombre, dtype: object

# %%
# Seleccionar múltiples columnas
datos_2[['Edad', 'Nota']]
# Out:
#     Edad  Nota
# 0     20   7.5
# 1     18   NaN
# 2     27   2.5
# 3     18   5.0
# 4     21  10.0
# 5     23   NaN
# 6     21   7.0
# 7     19   6.0
# 8     35   5.6
# 9     28   NaN
# 10    21   NaN
# 11    24   4.5
# 12    26  10.0
# 13    25   9.0
# 14    37   NaN
# 15    29   7.0
# 16    33   NaN
# 17    34   8.0

# %%
# Verificar los tipos de datos en cada columna
datos_2.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %%
df_1.dtypes
# Out:
# Tipo             object
# Colonia          object
# Habitaciones      int64
# Garages           int64
# Suites            int64
# Area              int64
# Valor           float64
# Condominio      float64
# Impuesto        float64
# dtype: object

# %% [markdown]
# Extra: Como la sugerencia misma mencionó, podemos utilizar un método de Pandas llamado describe para calcular algunas estadísticas descriptivas básicas de los datos en el DataFrame:

# %%
datos_2.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# El método describe() es una de las funciones más útiles de Pandas para el análisis exploratorio de datos. Se utiliza para calcular algunas estadísticas descriptivas básicas de los datos en un DataFrame o en una columna específica de un DataFrame.

# %% [markdown]
# # 10 Lo que aprendimos
#  Siguiente pregunta
#
# Lo que aprendimos en esta aula:
#
# * Importar la biblioteca Pandas;
# * Realizar la lectura de archivos csv;
# * Identificar un DataFrame;
# * Visualizar las primeras y últimas filas de un DataFrame;
# * Verificar la cantidad de filas y columnas de un DataFrame;
# * Comprobar los tipos de datos de cada columna de un DataFrame;
# * Seleccionar una o varias columnas.

# %% [markdown]
# ### 02 - Análisis exploratorio de lo datos
# ##**Demandas de ML**

# %% [markdown]
# ### **Análisis exploratorio de los datos**

# %% [markdown]
# #### ¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
df_1.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
df_1['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
df_1.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
df_1.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
df_1.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio = df_1.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# # 03 - Para saber más: entendiendo el método groupby
# El método groupby de Pandas permite agrupar y resumir datos de un DataFrame basado en uno o más criterios. Estos criterios pueden ser variables numéricas o categóricas, como columnas o índices del DataFrame.
#
# La idea detrás de groupby es dividir los datos en grupos basados en los criterios seleccionados y luego aplicar una operación a estos grupos. Esta operación puede ser una función de agregación, como suma, promedio, recuento, desviación estándar, entre otras, o incluso una operación personalizada definida por el usuario.
#
# Este método tiene varios parámetros, algunos de los cuales son:
#
# by: Este es el parámetro más común y se utiliza para especificar la columna o columnas por las cuales queremos agrupar. Como argumento, podemos pasar el nombre de una columna o una lista de nombres de columnas;
#
# axis: Utilizamos este parámetro para especificar el eje a lo largo del cual queremos agrupar. El valor predeterminado es 0, lo que significa que se agruparán las filas. Si deseamos agrupar las columnas, debemos establecer este parámetro en 1;
#
# sort: Este parámetro es un booleano (True o False) que indica si los grupos deben ordenarse por el valor de la columna de agrupación. El valor predeterminado es True;
#
# dropna: Utilizamos este parámetro para controlar si los valores faltantes (NaN) se eliminarán o no durante el proceso de agrupación. El valor predeterminado es True.
#
# Veamos un ejemplo simple utilizando groupby. Supongamos que tenemos el siguiente DataFrame:
#
# Código del DataFrame:

# %%
import pandas as pd

df = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
df
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %% [markdown]
# Aquí tenemos un DataFrame con datos sobre algunos animales. Usaremos groupby para agrupar los datos por tipo de animal y realizar la suma de la columna "Cantidad" para obtener el total de cada tipo de animal:

# %%
df.groupby('Animal').sum(numeric_only=True)
# Out:
#           Cantidad
# Animal
# Elefante         3
# Gato             5
# Perro            6

# %%
df.groupby('Color').sum(numeric_only=True)
# Out:
#         Cantidad
# Color
# Blanco         3
# Gris           1
# Marrón         6
# Negro          4

# %% [markdown]
# También podemos usar el método groupby para agrupar datos por múltiples columnas. Por ejemplo, agrupemos por tipo de animal y también por color, y realicemos la suma de la columna "Cantidad":

# %%
df.groupby(['Animal', 'Color'])[['Cantidad']].sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2

# %%
df.Color.unique()
# Out:
# array(['Negro', 'Blanco', 'Gris', 'Marrón'], dtype=object)

# %%
df.Animal.unique()
# Out:
# array(['Perro', 'Gato', 'Elefante'], dtype=object)

# %% [markdown]
# Así, podemos observar que groupby es un método muy útil para situaciones en las que necesitamos dividir los datos en grupos para analizar el comportamiento de estos grupos. Utilizando este método, podemos responder preguntas específicas sobre nuestros conjuntos de datos. Si desea aprender más sobre este método, le sugiero dos artículos:
#
# * Pandas GroupBy: Su guía para agrupar datos en Python;
# * Explicación detallada del groupby de Pandas.
#
# Ambos artículos están en inglés, pero se pueden traducir fácilmente utilizando la extensión de traducción de Google Chrome.

# %% [markdown]
# ## 04 - Inmuebles residenciales

# %%
df_1.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales = ['Conjunto Comercial/Sala', 'Edificio Completo', 'Tienda/Salón', 'Casa Comercial',
                         'Terreno Estándar', 'Cochera/Estacionamiento', 'Galpón/Depósito/Almacén',
                         'Tienda en Centro Comercial','Hotel', 'Loteo/Condominio','Industria']

# %%
df_1.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
df_1.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df_2 = df_1.query('@inmuebles_comerciales not in Tipo')
df_2.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
df_tipo_precio = df_2.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8),color='green')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# # 05 - Realizando selecciones con query
# El método query es una herramienta de Pandas que permite seleccionar datos en un DataFrame utilizando las condiciones que especificamos. Utiliza una sintaxis similar a SQL y es útil cuando necesitamos filtrar nuestros datos.
#
# Con base en esto, supongamos que el equipo de aprendizaje automático (ML) ha realizado la siguiente solicitud:
#
# Seleccione solo las propiedades que tienen una o más suites.
#
# ¿Cuál de las siguientes opciones presenta la forma correcta de realizar esta selección?
#
# * df.query('Suites >= 1')
#
#
# Excelente! Al pasar la expresión 'Suites >= 1' al método query, especificamos que queremos seleccionar las filas en las que la columna "Suites" tiene un valor mayor o igual a 1.

# %% [markdown]
# #### Porcentaje de cada tipo de inmueble presente en la base de datos

# %%
df_2.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df_2.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df_2.Tipo.value_counts(normalize=True) # Porcentajes
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
df_2.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df_3 = df_2.query('Tipo == "Departamento"')

# %%
df_3.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
porcentaje_tipo = df_2.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind='bar', figsize=(12,8),color='pink',xlabel='Tipos',ylabel='Porcentajes')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
df_3 = df_2.query('Tipo == "Departamento"')
df_3.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
df_3.shape
# Out:
# (14764, 9)

# %% [markdown]
# ##  07 - Métodos de la biblioteca Pandas
#
# La biblioteca Pandas tiene diferentes métodos que nos ayudan a analizar y explorar nuestros datos. Utilizando estos métodos, podemos agrupar datos, realizar selecciones, contar el número de valores únicos, entre otras cosas.
#
# Supongamos que necesitamos contar cuántas veces aparece cada barrio en nuestra base de datos. ¿Qué método podríamos utilizar para hacerlo?
#
# df['Barrio'].value_counts()
#
#
# El método value_counts() de Pandas se utiliza para devolver una serie que contiene recuentos de valores únicos en una columna u objeto Series de Pandas.

# %% [markdown]
# ##  08 - Para saber más: alterando los nombres de las columnas
#
# Cuando trabajamos con bases de datos, en ocasiones puede ser necesario cambiar los nombres de las columnas. Por ejemplo, cuando creamos el siguiente DataFrame en nuestro proyecto:
#
# df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
#
# Obtuvimos el siguiente resultado: imagen
#
# Podemos ver que la columna con los porcentajes está nombrada como "Tipo". ¿Y si quisiéramos cambiar su nombre a "Porcentajes"?
#
# En ese caso, podemos utilizar el método rename() para cambiar el nombre de esa columna. Este método nos permite especificar un diccionario que asocia el nombre antiguo de la columna con el nuevo nombre que deseamos asignar. Entonces, hagámoslo:
#
# # Guardando el DataFrame en una variable
# df_ejemplo = df['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo')
#
# # Cambiando el nombre de la columna "Tipo" a "Porcentajes"
# df_ejemplo.rename(columns={'Tipo': 'Porcentajes'}, inplace=True)
#
# # Visualizando el DataFrame
# df_ejemplo
#
# Hemos utilizado el parámetro inplace=True para que este cambio se aplique definitivamente en nuestro DataFrame df_ejemplo. Entonces, al visualizar el DataFrame, obtendremos el siguiente resultado: imagen

# %% [markdown]
# ###  09 Desafío: vamos a practicar
#
# Siguiente pregunta
#
# El equipo de ML ha llegado con algunas demandas de última hora que debemos resolver en este momento de análisis exploratorio. Estas demandas son las siguientes:
#
# * Calcular el promedio de habitaciones por departamento.
#
# * Verificar cuántas colonias únicas existen en nuestra base de datos.
#
# * Analizar qué colonias tienen el promedio de alquiler más alto.
#
# * Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %% [markdown]
# ## Opinión del instructor
#
# ¡Vamos a resolver estos desafíos!
#
# Es importante destacar que en algunas situaciones podemos utilizar diferentes métodos de Pandas para lograr lo mismo. Por lo tanto, las soluciones a continuación no son la única forma de abordar los desafíos planteados.
#
# 1 - Para calcular el promedio de habitaciones, podemos seleccionar la columna de interés y aplicar el método mean():

# %%
df_1['Habitaciones'].mean() #  Calcular el promedio de habitaciones por departamento.
# Out:
# np.float64(1.7488555391903189)

# %% [markdown]
# 2 - Una forma de verificar cuántos barrios únicos existen en la base de datos sería utilizando el método unique(), que nos devolverá una lista con los barrios únicos. Luego, podemos usar la función len para contar cuántos elementos hay en esa lista:

# %%
len(df_1['Colonia'].unique()) # Verificar cuántas colonias únicas existen en nuestra base de datos.
# Out:
# 88

# %% [markdown]
# Además, también podemos utilizar un método de Pandas que realiza directamente el conteo de elementos únicos en una columna específica. Este método es nunique():

# %%
df_1['Colonia'].nunique()
# Out:
# 88

# %% [markdown]
# 3 - Para analizar qué barrios tienen el promedio de valor de alquiler más alto, podemos:
#
# * Agrupar nuestra base de datos por la columna "Colonia".
# * Aplicar el método mean.
# * Colocar el resultado en un DataFrame y ordenarlo

# %%
df_1.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False) #  Analizar qué colonias tienen el promedio de alquiler más alto.
# Out:
#                               Valor
# Colonia
# San Juan Xalpa        420926.739130
# Nativitas             244684.395062
# La Merced             213292.770833
# Santa Marta Acatitla  166048.105263
# Villa de Cortés       135737.411765
# ...                             ...
# Álvaro Obregón          3048.281250
# San José Insurgentes    2660.000000
# El Rodeo                2586.111111
# Tláhuac                 2481.818182
# Las Aguilas             2222.500000
#
# [88 rows x 1 columns]

# %% [markdown]
# El parámetro ascending=False se utiliza en la función sort_values() para ordenar los valores en orden descendente (de mayor a menor).
#
# 4 - Como queremos crear un gráfico con solo las 5 colonias que tienen el promedio de alquiler más alto, podemos usar .head() para seleccionar las 5 primeras filas del DataFrame que creamos en el desafío 3 y guardar eso en una variable:

# %%
df_colonias = df_1.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False).head()

# %% [markdown]
# Luego, podemos crear el gráfico:

# %%
df_colonias.plot(kind='barh', figsize=(14,10), color='blue')
# Out:
# <Axes: ylabel='Colonia'>

# %% [markdown]
# ##  10 Lo que aprendimos
# Siguiente pregunta
#
# Lo que aprendimos en esta aula:
#
# * Identificar qué hacer durante un proceso de análisis exploratorio;
# * Calcular el promedio de valores de un DataFrame;
# * Agrupar los datos según una columna específica utilizando groupby;
# * Realizar selecciones utilizando el método query;
# * Transformar Series en DataFrames;
# * Ordenar valores de un DataFrame con sort_values;
# * Graficar barras verticales y horizontales;
# * Visualizar valores únicos con unique;
# * Utilizar value_counts para contar valores únicos y calcular porcentajes;
# * Cambiar nombres de columnas.

# %% [markdown]
# ### Tratamiento y filtrado de los datos

# %% [markdown]
# ### **Tratamiento de datos nulos**

# %%
df_3.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# 7      False    False         False    False   False  False  False
# 8      False    False         False    False   False  False  False
# 10     False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25111  False    False         False    False   False  False  False
# 25113  False    False         False    False   False  False  False
# 25114  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 3           False     False
# 4           False      True
# 7            True      True
# 8           False     False
# ...

# %%
df_3.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio       493
# Impuesto        3797
# dtype: int64

# %%
df_4 = df_3.fillna(0)

# %%
df_4.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ## 03 - Para saber más: lidiando con datos nulos
#
# Tratar datos nulos en una base de datos es muy importante porque estos datos faltantes pueden interferir directamente en la calidad de los análisis y los resultados obtenidos. Cuando hay datos nulos en un conjunto de datos, pueden surgir problemas como sesgo, reducción de la precisión y falta de precisión en la información obtenida.
#
# Además, algunos análisis y modelos estadísticos no pueden manejar la presencia de datos faltantes. Por lo tanto, el tratamiento de los datos nulos es fundamental para garantizar la confiabilidad y la precisión de los análisis y decisiones basadas en estos datos.
#
# Existen varias formas de tratar datos nulos con Pandas. Algunas de las formas principales son:
#
# Eliminar los datos nulos: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.
#
# Llenar los datos nulos: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.
#
# Interpolar los datos nulos: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.
#
# Es importante elegir la mejor forma de tratar los datos nulos según la situación específica y el objetivo del análisis de datos.

# %% [markdown]
# ### **Remover registros inconsistentes**

# %%
df_4.query('Valor==0 | Condominio==0')
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
df_4.query('Valor==0 | Condominio==0').index
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
df_remover = df_4.query('Valor==0 | Condominio==0').index

# %%
df_4.drop(df_remover,axis=0,inplace=True)

# %%
df_4.query('Valor==0 | Condominio==0').index
# Out:
# Index([], dtype='int64')

# %%
df_3.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
df_3.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
df_3.drop('Tipo',axis=1, inplace=True)
df_3.sample(10)
# Out:
# /tmp/ipykernel_4393/2101941060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_3.drop('Tipo',axis=1, inplace=True)
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 8618                Condesa             1        0       0    55   6650.0
# 7580               Santa Fe             4        3       4   255  56000.0
# 13058              Santa Fe             3        1       1    80   9800.0
# 18072  San Andrés Tetepilco             2        0       0    40   3465.0
# 21685  Lomas de Chapultepec             3        2       0   150  15750.0
# 15769              Santa Fe             3        3       3   248  13300.0
# 9436   Lomas de Chapultepec             3        2       1   143  35000.0
# ...

# %% [markdown]
# ##  05 Método drop()
#
# El método drop() de la biblioteca Pandas permite eliminar una o más filas y/o columnas de un DataFrame. Esta eliminación se puede realizar de forma permanente en el DataFrame original. Es posible especificar los índices de las filas y/o columnas que se deben eliminar, así como el eje en el que debe ocurrir la eliminación.
#
# Suponga que tenemos el siguiente DataFrame, guardado en una variable llamada "datos":
#
# Código para crear el DataFrame:

# %%
import pandas as pd

datos = pd.DataFrame([['Plaza', 'Cebolla', 2.5], 
                      ['Mercado', 'Cebolla', 1.99], 
                      ['Supermercado', 'Cebolla', 1.69], 
                      ['Plaza', 'Tomate', 4], 
                      ['Mercado', 'Tomate', 3.29], 
                      ['Supermercado', 'Tomate', 2.99], 
                      ['Plaza', 'Papa', 4.2], 
                      ['Mercado', 'Papa', 3.99], 
                      ['Supermercado', 'Papa', 3.69]],
                      columns = ['Comercio', 'Producto', 'Precio'])

# %%
datos
# Out:
#        Comercio Producto  Precio
# 0         Plaza  Cebolla    2.50
# 1       Mercado  Cebolla    1.99
# 2  Supermercado  Cebolla    1.69
# 3         Plaza   Tomate    4.00
# 4       Mercado   Tomate    3.29
# 5  Supermercado   Tomate    2.99
# 6         Plaza     Papa    4.20
# 7       Mercado     Papa    3.99
# 8  Supermercado     Papa    3.69

# %% [markdown]
# ¿Cuál de los siguientes códigos se podría utilizar para eliminar de forma permanente las filas en las que, en la columna "Comercio", tenemos "Supermercado"?
#
#
# datos.drop([2, 5, 8], axis=0, inplace=True)
#
# De esta manera, pasamos una lista con los índices de las filas en las que, en la columna "Comercio", tenemos "Supermercado", es decir, los índices de las filas que deseamos eliminar. También se especifica axis=0, lo que indica que deseamos eliminar filas.

# %%
datos.drop([2, 5, 8], axis=0, inplace=True)
datos
# Out:
#   Comercio Producto  Precio
# 0    Plaza  Cebolla    2.50
# 1  Mercado  Cebolla    1.99
# 3    Plaza   Tomate    4.00
# 4  Mercado   Tomate    3.29
# 6    Plaza     Papa    4.20
# 7  Mercado     Papa    3.99

# %% [markdown]
# ### **Creando filtros**

# %% [markdown]
# #### 1. Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
seleccion1 = df_3['Habitaciones'] == 1

# %%
seleccion1
# Out:
# 3         True
# 4         True
# 7         True
# 8         True
# 10       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Name: Habitaciones, Length: 14764, dtype: bool

# %%
type(seleccion1)
# Out:
# pandas.core.series.Series

# %%
df_3[seleccion1]
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 7          Centro Histórico             1        0       0    36   4200.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
seleccion2 = df_3['Valor'] < 4200
df_3[seleccion2]
# Out:
#                   Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3        Centro Histórico             1        0       0    15  2800.0
# 4               Del Valle             1        0       0    48  2800.0
# 19               Narvarte             1        0       0    48  2625.0
# 37       Centro Histórico             1        0       0    27  2625.0
# 61       Centro Histórico             1        1       0    37  3850.0
# ...                   ...           ...      ...     ...   ...     ...
# 25038  Villa de Guadalupe             2        1       0    50  2800.0
# 25051           Nativitas             2        1       0    62  3500.0
# 25065           Nativitas             2        1       0    50  3150.0
# 25095      Lindavista Sur             2        0       0    63  2800.0
# 25114            Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       NaN
# ...

# %%
df_3[seleccion2].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       176
# Valor                   4025.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
filtro1 = (seleccion1) & (seleccion2)
df_3[filtro1]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24892       Loma Bonita             1        0       0    40  1925.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       NaN
# 19         2702.0      87.5
# ...

# %%
df1 = df_3[filtro1]

# %% [markdown]
# #### 2. Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
filtro2 = (df_3['Habitaciones'] >= 2) & (df_3['Valor'] < 10500) & (df_3['Area'] > 70)
df_3[filtro2]
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          NaN
# 21          NaN
# ...

# %%
df2 = df_3[filtro2]

# %% [markdown]
# ##  07 - Realizando selecciones
#
# El equipo de Machine Learning solicitó realizar otro filtro en nuestra base de datos. Esta vez, el filtro sería para obtener la siguiente información:
#
# ¿Cuáles son los apartamentos que tienen un área mayor de 80 m² o un alquiler menor de MXN 4.000,00?
#
# Con base en esto, ¿cuál de las siguientes opciones presenta un código que se puede utilizar para obtener la información solicitada?
#
# seleccion = (df['Area'] > 80) | (df['Valor'] < 4000)
# df[seleccion]
#
# Muy bien, de esta manera, estamos realizando el filtro exactamente como lo solicitó el equipo de Machine Learning.

# %%
seleccion = (df_3['Area'] > 80) | (df_3['Valor'] < 4000)
df_3[seleccion]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3      Centro Histórico             1        0       0    15   2800.0
# 4             Del Valle             1        0       0    48   2800.0
# 10              Condesa             4        3       1   243  45500.0
# 14             Narvarte             2        1       0   110   6650.0
# 18             Coyoacán             3        1       1   125  24500.0
# ...                 ...           ...      ...     ...   ...      ...
# 25105          Santa Fe             2        1       1    85   7875.0
# 25106          Santa Fe             3        2       0    98   8050.0
# 25108          Santa Fe             3        2       2   140  19250.0
# 25113          Coyoacán             3        1       2   150  52500.0
# 25114          Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       NaN
# 10         7000.0    2810.5
# ...

# %% [markdown]
# ### **Guardando los archivos**

# %%
df_3.to_csv('inmuebles_ml_2.csv', index=False, sep=';')

# %%
pd.read_csv('inmuebles_ml_2.csv', sep=';')
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 0          Centro Histórico             1        0       0    15   2800.0
# 1                 Del Valle             1        0       0    48   2800.0
# 2          Centro Histórico             1        0       0    36   4200.0
# 3                   Condesa             1        0       1    40   7000.0
# 4                   Condesa             4        3       1   243  45500.0
# ...                     ...           ...      ...     ...   ...      ...
# 14759  Lomas de Chapultepec             3        0       1    80  10500.0
# 14760              Coyoacán             3        1       2   150  52500.0
# 14761              Narvarte             1        0       0    28   3500.0
# 14762               Mixcoac             2        1       0    48   4900.0
# 14763  Lomas de Chapultepec             2        0       0    70  10500.0
#
#        Condominio  Impuesto
# 0          1365.0      70.0
# ...

# %%
df.to_csv('inmuebles_ml.csv',index=False)

# %%
pd.read_csv('inmuebles_ml.csv')
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %%
df.to_csv('/content/drive/MyDrive/pandas/inmuebles_ml.csv',index=False, sep=';')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[240], line 1
# ----> 1 df.to_csv('/content/drive/MyDrive/pandas/inmuebles_ml.csv',index=False, sep=';')
#
# File ~/.pyenv/versions/3.10.13/envs/api-env/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df1.to_csv('/content/drive/MyDrive/pandas/inmuebles_ml_filtro1.csv',index=False, sep=';') # Para guardar en Google Drive
df2.to_csv('/content/drive/MyDrive/pandas/inmuebles_ml_filtro2.csv',index=False, sep=';')

# %%
df1.to_csv('inmuebles_ml_filtro1.csv',index=False, sep=';') # 1 habitación y menos de 4000 pesos
df2.to_csv('inmuebles_ml_filtro2.csv',index=False, sep=';') # 2. Apartamentos que tienen al menos 2 
# dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m²

# %%
pd.read_csv('inmuebles_ml_filtro1.csv', sep=';') # 1
# Out:
#               Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 0    Centro Histórico             1        0       0    15  2800.0
# 1           Del Valle             1        0       0    48  2800.0
# 2            Narvarte             1        0       0    48  2625.0
# 3    Centro Histórico             1        0       0    27  2625.0
# 4    Centro Histórico             1        1       0    37  3850.0
# ..                ...           ...      ...     ...   ...     ...
# 418        Peralvillo             1        0       1    69  3150.0
# 419        La Condesa             1        0       0    46  3850.0
# 420       Loma Bonita             1        0       0    40  1925.0
# 421              Roma             1        0       0    21  3500.0
# 422          Narvarte             1        0       0    28  3500.0
#
#      Condominio  Impuesto
# 0        1365.0      70.0
# 1         805.0       NaN
# 2        2702.0      87.5
# 3        1298.5      66.5
# ...

# %%
pd.read_csv('inmuebles_ml_filtro2.csv', sep=';') # 2
# Out:
#         Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 0      Narvarte             2        1       0   110  6650.0      2450.0
# 1      Narvarte             2        1       0    78  7000.0      2450.0
# 2          Roma             2        1       0    76  8750.0      2590.0
# 3      Santa Fe             3        1       1    72  8225.0      2100.0
# 4      Santa Fe             3        2       1   104  9100.0      4774.0
# ...         ...           ...      ...     ...   ...     ...         ...
# 2702  Del Valle             2        0       1    90  7700.0      1890.0
# 2703   Santa Fe             2        1       1    72  5950.0      3045.0
# 2704   Narvarte             3        1       0    75  6650.0      3010.0
# 2705   Santa Fe             2        1       1    85  7875.0      5463.5
# 2706   Santa Fe             3        2       0    98  8050.0      3104.5
#
#       Impuesto
# 0        483.0
# 1          NaN
# 2          NaN
# 3        245.0
# ...

# %% [markdown]
# ## Desafío: guardando los datos filtrados
#
#
# Durante el desarrollo de nuestro proyecto, aplicamos algunos filtros a nuestra base de datos y guardamos los DataFrames resultantes en diferentes variables, denominadas df1 y df2.
#
# Con base en esto, guarda estos DataFrames en 2 archivos CSV diferentes para que el equipo de ML pueda acceder a estos datos de manera más conveniente.
#
# Opinión del instructor
#
# Para guardar estos DataFrames en formato CSV, podemos utilizar el método to_csv que ya conocemos:
#
# * df1.to_csv('inmuebles_ml_filtro1.csv', index=False, sep=";")
# * df2.to_csv('inmuebles_ml_filtro2.csv', index=False, sep=";")
#
# Con los archivos guardados, también puede ser interesante leer cada uno de ellos utilizando read_csv() para asegurarse de que todo se haya realizado correctamente.

# %% [markdown]
# ### 10 - Para saber más: exportando diferentes formatos
#
#
# Pandas proporciona varios métodos para guardar archivos en diferentes formatos. Algunos ejemplos son:
#
# to_csv(): Guarda el DataFrame en un archivo CSV (Valores Separados por Comas).
#
# to_excel(): Guarda el DataFrame en un archivo de Excel.
#
# to_json(): Guarda el DataFrame en un archivo JSON (Notación de Objetos JavaScript).
#
# Estos son solo algunos ejemplos, existen otros métodos disponibles en Pandas para guardar archivos en diferentes formatos. Si deseas conocerlos, consulta la documentación:
#
# User Guide - IO Tools

# %% [markdown]
# ### 11 - Desafío: vamos a practicar
#
#
# Para practicar los métodos aprendidos a lo largo de esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.
#
# Este archivo es el mismo que se utilizó para resolver los desafíos de la lección 1 y contiene datos de estudiantes de un curso superior.
#
# Basándonos en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# 1-Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
#
# 2-Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
#
# 3-Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.
#
# 4-Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".
#
# Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor" puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %% [markdown]
# ### Opinión del instructor
#
# ¡Vamos a resolver estos desafíos!
#
# Es importante destacar que en algunas situaciones, podemos utilizar diferentes métodos de Pandas para lograr lo mismo. Por lo tanto, las soluciones a continuación no son la única forma de abordar los desafíos planteados.
#
# 1 - Podemos comenzar verificando la existencia de datos nulos:

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos = pd.read_csv(url)
print(datos.head()) # Para ver las primeras filas del DataFrame
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
print(datos.isnull().sum())
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %% [markdown]
# Con el resultado, notaremos que solo la columna "Nota" contiene datos nulos. En este caso, podemos suponer que los estudiantes sin calificación probablemente tenían un 0. Por lo tanto, podemos reemplazar los valores nulos por 0:

# %%
datos = datos.fillna(0)
print(datos.isnull().sum()) # Para verificar que ya no hay nulos
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# 2 - Para eliminar a los estudiantes "Alicia" y "Carlos" de nuestra base de datos, necesitamos obtener los índices de las filas donde se encuentran sus nombres y utilizar el método drop para eliminar las filas respectivas:

# %%
alumnos_a_eliminar = datos.query('Nombre == "Alicia" | Nombre == "Carlos"').index
datos.drop(alumnos_a_eliminar, axis=0, inplace=True)
print(datos) # Para ver el DataFrame sin Alicia y Carlos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# 3 - En este caso, nuestro primer paso es crear una variable en la que seleccionamos solo a los estudiantes aprobados:

# %%
#seleccion = datos['Aprobado'] == 'True'
seleccion = (datos['Aprobado'] == 'True') | (datos['Aprobado'] == 'Verdadero')
alumnos_aprobados = datos[seleccion]
print(alumnos_aprobados) # DataFrame con solo alumnos aprobados
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# 4 - Para guardar el DataFrame con solo los estudiantes aprobados, podemos comenzar guardando el DataFrame resultante del desafío 3 en una variable:

# %%
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)
print("El archivo 'alumnos_aprobados.csv' ha sido guardado.")
# Out:
# El archivo 'alumnos_aprobados.csv' ha sido guardado.

# %% [markdown]
# Luego, podemos usar el método to_csv para guardarlo en formato CSV:

# %%
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)

# %% [markdown]
# Extra: El método replace se utiliza para reemplazar un valor específico por otro. En el caso de nuestra base de datos, queremos reemplazar los valores 7.0 por 8.0. Para hacerlo, podemos usar el siguiente fragmento de código:

# %%
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)
print(alumnos_aprobados) # DataFrame de aprobados con las notas actualizadas
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %% [markdown]
# Y para guardar este cambio de forma definitiva, podemos asignarlo a nuestra variable:

# %%
print(datos['Aprobado'].value_counts())
# Out:
# Aprobado
# False        9
# True         6
# Verdadero    1
# Name: count, dtype: int64

# %%
datos[['Nota']]
# Out:
#     Nota
# 0    7.5
# 1    0.0
# 2    2.5
# 3    5.0
# 4   10.0
# 5    0.0
# 6    7.0
# 9    0.0
# 10   0.0
# 11   4.5
# 12  10.0
# 13   9.0
# 14   0.0
# 15   7.0
# 16   0.0
# 17   8.0

# %% [markdown]
# ¡No olvides practicar para consolidar todos los conceptos que has aprendido!

# %%
import pandas as pd

# Cargar los datos
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos = pd.read_csv(url)

# 1. Verificar y tratar datos nulos
print("Valores nulos antes del tratamiento:")
print(datos.isnull().sum())
datos = datos.fillna(0)
print("\nValores nulos después del tratamiento:")
print(datos.isnull().sum())

# 2. Eliminar a los estudiantes "Alicia" y "Carlos"
alumnos_a_eliminar = datos.query('Nombre == "Alicia" | Nombre == "Carlos"').index
datos.drop(alumnos_a_eliminar, axis=0, inplace=True)
print("\nDataFrame después de eliminar a Alicia y Carlos:")
print(datos)

# 3. Filtrar estudiantes aprobados (considerando 'True' y 'Verdadero')
seleccion = (datos['Aprobado'] == 'True') | (datos['Aprobado'] == 'Verdadero')
alumnos_aprobados = datos[seleccion]
print("\nDataFrame de alumnos aprobados:")
print(alumnos_aprobados)

# 4. Guardar el DataFrame de aprobados en un archivo CSV
alumnos_aprobados.to_csv('alumnos_aprobados.csv', index=False)
print("\nEl archivo 'alumnos_aprobados.csv' ha sido guardado.")

# Extra: Reemplazar calificaciones de 7.0 con 8.0 en el DataFrame de aprobados
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)
print("\nDataFrame de alumnos aprobados con calificaciones actualizadas:")
print(alumnos_aprobados)
# Out:
# Valores nulos antes del tratamiento:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64
#
# Valores nulos después del tratamiento:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64
#
# DataFrame después de eliminar a Alicia y Carlos:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero
#
# DataFrame de alumnos aprobados:
# ...

# %%
print(datos) # Este DataFrame
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
seleccion = (datos['Aprobado'] == True) | (datos['Aprobado'] == 'Verdadero')
alumnos_aprobados = datos[seleccion]
print(alumnos_aprobados)
# Out:
#    Nombre  Edad  Nota   Aprobado
# 17  Nadia    34   8.0  Verdadero

# %%
seleccion = (datos['Aprobado'] == 'True') | (datos['Aprobado'] == 'Verdadero') # mismo código pero con comillas en true
alumnos_aprobados = datos[seleccion]
print(alumnos_aprobados)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
print(datos[['Nombre', 'Aprobado']])
# Out:
#       Nombre   Aprobado
# 0    Alberto       True
# 1        Ana      False
# 2     Camila      False
# 3      David      False
# 4      Brian       True
# 5      Bruna      False
# 6    Daniela       True
# 9     Victor      False
# 10    Danilo      False
# 11   Ignacio      False
# 12  Stephany       True
# 13    Miriam       True
# 14     Pablo      False
# 15    Milena       True
# 16     Lucas      False
# 17     Nadia  Verdadero

# %%
seleccion = (datos['Aprobado'] == True) | (datos['Aprobado'] == 'Verdadero')
alumnos_aprobados = datos[seleccion]
print(alumnos_aprobados)
# Out:
#    Nombre  Edad  Nota   Aprobado
# 17  Nadia    34   8.0  Verdadero

# %%
print(datos['Aprobado'].apply(type).unique())
# Out:
# [<class 'str'>]

# %% [markdown]
# Gemini:
# ¡Ajá! Ahí está la clave. Como la salida de datos['Aprobado'].apply(type).unique() es [<class 'str'>], esto significa que todos los valores en la columna 'Aprobado' son cadenas de texto (strings), no booleanos.
#
# Por lo tanto, cuando hacemos la comparación datos['Aprobado'] == True, estamos comparando una cadena de texto con un valor booleano, lo cual siempre resultará en False. Lo mismo ocurre con la comparación con 'Verdadero', que sí funciona porque estamos comparando cadenas de texto.
#
# Para solucionar esto, necesitamos ajustar nuestra condición de selección para comparar con las cadenas de texto "True" y "Verdadero".
#
# Modifica la línea de selección de esta manera:

# %%
seleccion = (datos['Aprobado'] == 'True') | (datos['Aprobado'] == 'Verdadero')
alumnos_aprobados = datos[seleccion]
print(alumnos_aprobados)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
alumnos_aprobados = alumnos_aprobados.replace(7.0, 8.0)
print("\nDataFrame de alumnos aprobados con calificaciones actualizadas:")
print(alumnos_aprobados)
# Out:
# DataFrame de alumnos aprobados con calificaciones actualizadas:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   8.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   8.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
alumnos_aprobados.to_csv('alumnos_aprobados_final.csv', index=False)
print("\nEl DataFrame de alumnos aprobados final ha sido guardado en 'alumnos_aprobados_final.csv'")
# Out:
# El DataFrame de alumnos aprobados final ha sido guardado en 'alumnos_aprobados_final.csv'

# %% [markdown]
# ###  12 Lo que aprendimos
#
#
# Lo que aprendimos en esta aula:
#
# * Verificar si una base de datos tiene datos nulos;
# * Tratar los datos nulos;
# * Eliminar filas y columnas de un DataFrame;
# * Realizar diferentes selecciones en una base de datos;
# * Guardar datos en formato csv;
# * Utilizar el método replace para reemplazar valores en una base de datos.

# %% [markdown]
# ## **Demandas de DEV**

# %% [markdown]
# ### **Crear columnas numéricas**

# %% [markdown]
# #### 1. valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.

# %%
import pandas as pd
datos = pd.read_csv('../data/alquiler.csv', sep=';')
datos.shape
# Out:
# (25121, 9)

# %%
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos['Valor_mensual'] = datos['Valor'] + datos['Condominio']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# 2. valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.

# %%
datos['Valor_anual'] = datos['Valor_mensual'] * 12 + datos['Impuesto']
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ## 03 - Operaciones entre columnas
#
# Supongamos que tenemos el siguiente DataFrame con información sobre algunos autos en venta:
#
# Código para crear el DataFrame:

# %%
import pandas as pd

datos = {
    'Nombre': ['Jetta', 'Passat', 'Crossfox', 'DS5', 'Escarabajo'], 
    'Motor': ['Motor 4.0 Turbo', 'Motor Diesel', 'Motor Diesel V8', 'Motor 2.0', 'Motor 1.6'],
    'Modelo': [2019, 2003, 1991, 2019, 1990],
    'Kilometraje': [0.0, 5712.0, 37123.0, 0.0, 120000.0],
    'Valor': [88000.0, 106000.0, 72000.0, 89000.0, 32000.0],
    'Impuesto': [2000.0, 5000.0, 1700.0, 2200.0, 1000.0],
    'Descuento': [380.0, 450.0, 277.0, 400.0, 150.0]
}

df = pd.DataFrame(datos)
df
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento
# 0      380.0
# 1      450.0
# 2      277.0
# 3      400.0
# 4      150.0

# %%
print(df)
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento
# 0      380.0
# 1      450.0
# 2      277.0
# 3      400.0
# 4      150.0

# %% [markdown]
# Necesitamos crear una columna llamada "Valor_total" que tenga el valor del automóvil, sumado al impuesto y menos el valor del descuento. ¿Cuál de las siguientes opciones presenta el código correcto para crear esta columna?
#
# Alternativa correta

# %%
df['Valor_total'] = df['Valor'] + df['Impuesto'] - df['Descuento']
df
# Out:
#        Nombre            Motor  Modelo  Kilometraje     Valor  Impuesto  \
# 0       Jetta  Motor 4.0 Turbo    2019          0.0   88000.0    2000.0
# 1      Passat     Motor Diesel    2003       5712.0  106000.0    5000.0
# 2    Crossfox  Motor Diesel V8    1991      37123.0   72000.0    1700.0
# 3         DS5        Motor 2.0    2019          0.0   89000.0    2200.0
# 4  Escarabajo        Motor 1.6    1990     120000.0   32000.0    1000.0
#
#    Descuento  Valor_total
# 0      380.0      89620.0
# 1      450.0     110550.0
# 2      277.0      73423.0
# 3      400.0      90800.0
# 4      150.0      32850.0

# %% [markdown]
# De esta manera, estamos creando correctamente una nueva columna a partir de operaciones entre las columnas "Valor", "Impuesto" y "Descuento", según se solicitó.

# %% [markdown]
# ### **Crear columnas categóricas**

# %% [markdown]
# #### Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos['Descripcion'] = datos['Tipo'] + datos['Colonia']

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto                      Descripcion
# 0    40   5950.0      1750.0     210.0                  CocinetaCondesa
# 1   100  24500.0         NaN       NaN                      CasaPolanco
# 2   150  18200.0     14070.0    3888.5  Conjunto Comercial/SalaSanta Fe
# 3    15   2800.0      1365.0      70.0     DepartamentoCentro Histórico
# 4    48   2800.0       805.0       NaN            DepartamentoDel Valle

# %%
#datos['Descripcion'] = datos['Tipo'] + ' en la colonia ' +datos['Colonia'] + \
#                        ' con '+ datos['Habitaciones'] + ' cuarto(s) y '  + \
#                        datos['Garages'] + ' plazas de estacionamiento.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
datos['Descripcion'] = datos['Tipo'] + ' en la colonia ' +datos['Colonia'] + \
                        ' con '+ datos['Habitaciones'].astype(str) + ' cuarto(s) y '  + \
                        datos['Garages'].astype(str) + ' plazas de estacionamiento.'

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  \
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN
#
#                                          Descripcion
# 0  Cocineta en la colonia Condesa con 1 cuarto(s)...
# 1  Casa en la colonia Polanco con 2 cuarto(s) y 0...
# 2  Conjunto Comercial/Sala en la colonia Santa Fe...
# 3  Departamento en la colonia Centro Histórico co...
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la colonia Napoles con 1 cuarto(s) y 0 plazas de estacionamiento.'

# %% [markdown]
# ### 05 Para saber más: creando columnas
#
# Hay varias formas de crear columnas en un DataFrame en Pandas. Algunos ejemplos son:

# %% [markdown]
# ### 1 - Asignación directa de valores a una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = [7, 8, 9]
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# ### 2 - Creación de una columna a partir de operaciones entre otras columnas:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']
df
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %% [markdown]
# ### 3 - Uso del método assign() para crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df = df.assign(C=[7, 8, 9])
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# ### 4 - Uso del método apply() para aplicar una función a una columna existente y crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'].apply(lambda x: x * 2)
df
# Out:
#    A  B  C
# 0  1  4  2
# 1  2  5  4
# 2  3  6  6

# %% [markdown]
# Si deseas profundizar en este tema, consulta la documentación:
#
# * How to create new columns derived from existing columns

# %% [markdown]
# #### 2. Tiene_suite: Esta debe ser una columna que indique únicamente si la propiedad tiene o no suites, sin importar la cantidad.

# %%
datos['Tiene_suite'] = datos['Suites'].apply(lambda x: 'Sí' if x > 0 else 'No')

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  \
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN
#
#                                          Descripcion Tiene_suite
# 0  Cocineta en la colonia Condesa con 1 cuarto(s)...          No
# 1  Casa en la colonia Polanco con 2 cuarto(s) y 0...          Sí
# 2  Conjunto Comercial/Sala en la colonia Santa Fe...          No
# ...

# %%
datos.to_csv('/content/drive/MyDrive/pandas/inmuebles_dev.csv', index=False, sep=';')

# %%
datos.to_csv('inmuebles_dev.csv',index=False, sep=';')

# %% [markdown]
# ###  07 - Desafío: vamos a practica
#
# Para practicar los métodos aprendidos en esta lección y aprender nuevos, realizaremos algunos tratamientos y selecciones utilizando un archivo CSV diferente: alumnos.csv.
#
# Este archivo es el mismo que se utilizó para resolver los desafíos de las aulas 1 y 3 y contiene datos de estudiantes de un curso superior. Con base en esto, resolvamos los problemas propuestos a continuación utilizando los conocimientos adquiridos hasta ahora.
#
# * 1-Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.
#
# * 2-Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.
#
# * 3-Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# * True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# * False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).
#
# * 4-Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.
#
# Si necesitas ayuda, en la sección "Opinión del Instructor", puedes encontrar algunas formas de resolver los desafíos propuestos anteriormente.

# %% [markdown]
# ## Opinión del instructor
#
# ¡Vamos a resolver estos desafíos!
#
# Es importante destacar que en algunas situaciones, podemos utilizar diferentes métodos de Pandas para lograr lo mismo. Por lo tanto, las soluciones a continuación no son la única forma de abordar los desafíos planteados.
#
# * 1 - Para crear la columna "Puntos_extras", podemos utilizar el método apply para aplicar una función a la columna "Nota". Esta función debe multiplicar 0.4 por el valor de la nota de cada estudiante y colocar el resultado en nuestra nueva columna:

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos = pd.read_csv(url)
datos.head() # Para ver las primeras filas del DataFrame
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 704.0+ bytes

# %%
datos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos = datos.fillna(0)
datos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %%
datos.head()
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   0.0    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True

# %%
# 1 - Crear la columna "Puntos_extras"
datos['Puntos_extras'] = datos['Nota'].apply(lambda x: x * 0.4)
datos[['Nombre', 'Nota', 'Puntos_extras']].head()
# Out:
#     Nombre  Nota  Puntos_extras
# 0  Alberto   7.5            3.0
# 1      Ana   0.0            0.0
# 2   Camila   2.5            1.0
# 3    David   5.0            2.0
# 4    Brian  10.0            4.0

# %%
# 2 - Crear la columna "Notas_finales"
datos['Notas_finales'] = datos['Nota'] + datos['Puntos_extras']
datos[['Nombre', 'Nota', 'Puntos_extras', 'Notas_finales']].head()
# Out:
#     Nombre  Nota  Puntos_extras  Notas_finales
# 0  Alberto   7.5            3.0           10.5
# 1      Ana   0.0            0.0            0.0
# 2   Camila   2.5            1.0            3.5
# 3    David   5.0            2.0            7.0
# 4    Brian  10.0            4.0           14.0

# %%
# 3 - Crear la columna "Aprobado_final"
datos['Aprobado_final'] = datos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)
datos[['Nombre', 'Notas_finales', 'Aprobado', 'Aprobado_final']].head()
# Out:
#     Nombre  Notas_finales Aprobado  Aprobado_final
# 0  Alberto           10.5     True            True
# 1      Ana            0.0    False           False
# 2   Camila            3.5    False           False
# 3    David            7.0    False            True
# 4    Brian           14.0     True            True

# %%
print(datos[['Nombre', 'Aprobado', 'Aprobado_final']])
print("\nTipos de datos de las columnas 'Aprobado' y 'Aprobado_final':")
print(datos[['Aprobado', 'Aprobado_final']].dtypes)
# Out:
#       Nombre   Aprobado  Aprobado_final
# 0    Alberto       True            True
# 1        Ana      False           False
# 2     Camila      False           False
# 3      David      False            True
# 4      Brian       True            True
# 5      Bruna      False           False
# 6    Daniela       True            True
# 7     Carlos      False            True
# 8     Alicia      False            True
# 9     Victor      False           False
# 10    Danilo      False           False
# 11   Ignacio      False           False
# 12  Stephany       True            True
# 13    Miriam       True            True
# 14     Pablo      False           False
# 15    Milena       True            True
# 16     Lucas      False           False
# 17     Nadia  Verdadero            True
#
# Tipos de datos de las columnas 'Aprobado' y 'Aprobado_final':
# Aprobado          object
# Aprobado_final      bool
# dtype: object

# %%
datos['Aprobado_booleano'] = datos['Aprobado'].apply(lambda x: True if str(x).lower() == 'true' or str(x).lower() == 'verdadero' else False)
print(datos[['Nombre', 'Aprobado', 'Aprobado_booleano', 'Aprobado_final']].head())

seleccion_corregida = (datos['Aprobado_booleano'] == False) & (datos['Aprobado_final'] == True)
print("\nEstudiantes que cambiaron su estado a Aprobado (corregido):\n", datos[seleccion_corregida])
# Out:
#     Nombre Aprobado  Aprobado_booleano  Aprobado_final
# 0  Alberto     True               True            True
# 1      Ana    False              False           False
# 2   Camila    False              False           False
# 3    David    False              False            True
# 4    Brian     True               True            True
#
# Estudiantes que cambiaron su estado a Aprobado (corregido):
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final  \
# 3   David    18   5.0    False           2.00           7.00            True
# 7  Carlos    19   6.0    False           2.40           8.40            True
# 8  Alicia    35   5.6    False           2.24           7.84            True
#
#    Aprobado_booleano
# 3              False
# 7              False
# 8              False

# %%
print(datos[['Nombre', 'Nota', 'Aprobado', 'Notas_finales', 'Aprobado_final']])
# Out:
#       Nombre  Nota   Aprobado  Notas_finales  Aprobado_final
# 0    Alberto   7.5       True          10.50            True
# 1        Ana   0.0      False           0.00           False
# 2     Camila   2.5      False           3.50           False
# 3      David   5.0      False           7.00            True
# 4      Brian  10.0       True          14.00            True
# 5      Bruna   0.0      False           0.00           False
# 6    Daniela   7.0       True           9.80            True
# 7     Carlos   6.0      False           8.40            True
# 8     Alicia   5.6      False           7.84            True
# 9     Victor   0.0      False           0.00           False
# 10    Danilo   0.0      False           0.00           False
# 11   Ignacio   4.5      False           6.30           False
# 12  Stephany  10.0       True          14.00            True
# 13    Miriam   9.0       True          12.60            True
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch

# Colores basados en la aprobación original
colores_original = np.where(datos['Aprobado_booleano'], 'lightgreen', 'salmon')

# Colores basados en la aprobación final
colores_final = np.where(datos['Aprobado_final'], 'green', 'red')

# Posiciones de las barras
x = np.arange(len(datos['Nombre']))
width = 0.35

fig, ax = plt.subplots(figsize=(16, 8))
rects1 = ax.bar(x - width/2, datos['Nota'], width, label='Nota Original', color=colores_original)
rects2 = ax.bar(x + width/2, datos['Notas_finales'], width, label='Nota Final', color=colores_final)

# Añadir etiquetas y título
ax.set_ylabel('Nota')
ax.set_title('Comparación de Notas Originales y Finales por Estudiante por Pol Monsalvo & Gemini')
ax.set_xticks(x)
ax.set_xticklabels(datos['Nombre'], rotation=45, ha='right')
ax.grid(axis='y', linestyle='--')

# Crear leyenda personalizada
legend_elements = [Patch(facecolor='lightgreen', edgecolor='black', label='Aprobado (Original)'),
                   Patch(facecolor='salmon', edgecolor='black', label='No Aprobado (Original)'),
                   Patch(facecolor='green', edgecolor='black', label='Aprobado (Final)'),
                   Patch(facecolor='red', edgecolor='black', label='No Aprobado (Final)')]

ax.legend(handles=legend_elements, loc='upper right')

fig.tight_layout()
plt.show()

# %% [markdown]
# ##  09 Lo que aprendimos
#
#
# Lo que aprendimos en esta aula:
#
# * Generar columnas numéricas;
# * Insertar columnas categóricas;
# * Definir columnas binarias;
# * Realizar operaciones entre columnas;
# * Utilizar el método apply;
# * Crear funciones lambda.
